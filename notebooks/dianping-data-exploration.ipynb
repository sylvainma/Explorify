# %%
# %matplotlib notebook

import os
import sys
from operator import itemgetter
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from ipyleaflet import (Map, GeoJSON)

sns.set()

from sklearn.cluster import DBSCAN

import matplotlib.dates as mdates
from matplotlib.colors import rgb2hex
import json

def get_geojson(features):
    return {
        'type': 'FeatureCollection',
        'features': features
    }

def save_geojson(features, directory, file_name):
    if not os.path.exists(directory): os.makedirs(directory)
    f = os.path.join(directory, file_name + '.geojson')
    geojson = {
      'type': 'FeatureCollection',
      'features': features
    }
    with open(f, 'w') as outfile:
        json.dump(geojson, outfile, indent = 4)
    print('Saved to ' + f)

def to_geojson(df, groupby, lat, lng, cols, dumps=True):

    def get_features(row, color):
        properties = { k: str(v) for k,v in zip(cols,[row[col] for col in cols]) }
        properties['marker-color'] = rgb2hex(color[:3])
        return {
            'type': 'Feature',
                'geometry': {
                'type': 'Point',
                'coordinates': [row[lng], row[lat]]
            },
            'properties': properties
        }

    clusters = df.groupby(groupby)

    features = []
    colors = plt.cm.Spectral(np.linspace(0, 1, len(clusters)))
    for name, group in clusters:
        i = np.random.randint(colors.shape[0])
        color = colors[i]
        group.apply(lambda row: features.append(get_features(row, color)), axis=1)
        colors = np.delete(colors, i, 0)

    if dumps:
        return json.dumps(get_geojson(features))
    return get_geojson(features)

# %%
nb_dir = os.path.normpath(os.path.join(os.getcwd(), '..'))
os.listdir(nb_dir)
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

f = '../data/UTSEUS-shanghai-dianping.db'

# %%
import sqlite3
conn = sqlite3.connect(f)
cursor = conn.cursor()
cursor.execute("""
SELECT tag, longitude, latitude, c.category, avg_rating, avg_price, v.business_id, name, city
FROM venues v
LEFT OUTER JOIN venue_categories vc ON (v.business_id = vc.business_id)
    LEFT OUTER JOIN categories c ON (vc.category = c.category)
        LEFT OUTER JOIN venues_tags vt ON (v.business_id = vt.business_id)
WHERE
 (c.parent = '美食' OR c.category = '美食')
    AND longitude > 115
    AND longitude < 123
    AND avg_price > 0
""")
venues = pd.DataFrame(cursor.fetchall())
venues.columns = ['cn_tag', 'longitude', 'latitude', 'category', 'avg_rating', 'avg_price', 'business_id', 'name', 'city']

# %%
venues.head()
# Out:
#   cn_tag   longitude   latitude category  avg_rating  avg_price  business_id  \
# 0    囊包肉  121.490440  31.288305      新疆菜        30.0       81.0       500000
# 1    大盘鸡  121.490440  31.288305      新疆菜        30.0       81.0       500000
# 2    羊肉串  121.490440  31.288305      新疆菜        30.0       81.0       500000
# 3     菌类  121.445274  31.246317      云南菜        30.0       71.0       500146
# 4    菌菇类  121.445274  31.246317      云南菜        30.0       71.0       500146
#
#                                            name city
# 0  阿凡提美食娱乐城(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)   上海
# 1  阿凡提美食娱乐城(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)   上海
# 2  阿凡提美食娱乐城(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)   上海
# 3       傣家村(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)   上海
# 4       傣家村(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)   上海

# %%
grouped = venues.groupby('business_id')['cn_tag'].apply(list)

# %%
venues = venues.drop_duplicates(subset=list(venues)[1:]).drop('cn_tag', axis=1)

# %%
result = pd.merge(venues, grouped.reset_index(), on='business_id')

# %%
len(result.index)
result.head()
# Out:
#     longitude   latitude category  avg_rating  avg_price  business_id  \
# 0  121.490440  31.288305      新疆菜        30.0       81.0       500000
# 1  121.445274  31.246317      云南菜        30.0       71.0       500146
# 2  121.460140  31.221214       湘菜        35.0       95.0       500156
# 3  121.499664  31.239138      自助餐        30.0      296.0       500164
# 4  121.443830  31.201677      自助餐        35.0      217.0       500201
#
#                                              name city               cn_tag
# 0    阿凡提美食娱乐城(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)   上海      [囊包肉, 大盘鸡, 羊肉串]
# 1         傣家村(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)   上海       [菌类, 菌菇类, 菠萝饭]
# 2         滴水洞(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)   上海  [剁椒鱼头, 孜然排骨, 酸豆角肉末]
# 3    东方明珠旋转餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)   上海      [三文鱼, 法式蜗牛, 风景]
# 4  富豪环球白玉兰西餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)   上海        [三文鱼, 牛排, 甜品]

# %%
result.to_dict(orient='records')
# Out:
# [{'avg_price': 81.0,
#   'avg_rating': 30.0,
#   'business_id': 500000,
#   'category': '新疆菜',
#   'city': '上海',
#   'cn_tag': ['囊包肉', '大盘鸡', '羊肉串'],
#   'latitude': 31.288305,
#   'longitude': 121.49044,
#   'name': '阿凡提美食娱乐城(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 71.0,
#   'avg_rating': 30.0,
#   'business_id': 500146,
#   'category': '云南菜',
#   'city': '上海',
#   'cn_tag': ['菌类', '菌菇类', '菠萝饭'],
#   'latitude': 31.246317,
#   'longitude': 121.445274,
#   'name': '傣家村(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 95.0,
#   'avg_rating': 35.0,
#   'business_id': 500156,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['剁椒鱼头', '孜然排骨', '酸豆角肉末'],
#   'latitude': 31.221214,
#   'longitude': 121.46014,
#   'name': '滴水洞(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 296.0,
#   'avg_rating': 30.0,
#   'business_id': 500164,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '法式蜗牛', '风景'],
#   'latitude': 31.239138,
#   'longitude': 121.499664,
#   'name': '东方明珠旋转餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 217.0,
#   'avg_rating': 35.0,
#   'business_id': 500201,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '牛排', '甜品'],
#   'latitude': 31.201677,
#   'longitude': 121.44383,
#   'name': '富豪环球白玉兰西餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 77.0,
#   'avg_rating': 30.0,
#   'business_id': 500205,
#   'category': '韩国料理',
#   'city': '上海',
#   'cn_tag': ['三花肉', '牛肉', '葱油饼'],
#   'latitude': 31.215359,
#   'longitude': 121.42254,
#   'name': '高丽烧烤(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 61.0,
#   'avg_rating': 35.0,
#   'business_id': 500211,
#   'category': '素菜',
#   'city': '上海',
#   'cn_tag': ['素鸭', '蟹粉', '蟹粉豆腐'],
#   'latitude': 31.230803,
#   'longitude': 121.468575,
#   'name': '功德林(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 126.0,
#   'avg_rating': 35.0,
#   'business_id': 500212,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['剁椒鱼头', '干锅酸笋鸡', '竹筒牛蛙'],
#   'latitude': 31.22051,
#   'longitude': 121.45054,
#   'name': '古意湘味浓(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 72.0,
#   'avg_rating': 30.0,
#   'business_id': 500239,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['厚百叶', '酸梅汤', '骨头锅'],
#   'latitude': 31.202675,
#   'longitude': 121.46203,
#   'name': '好友汇砂锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 121.0,
#   'avg_rating': 35.0,
#   'business_id': 500256,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['乳鸽', '卤水拼盘', '红子鸡'],
#   'latitude': 31.24766,
#   'longitude': 121.44506,
#   'name': '红子鸡(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 147.0,
#   'avg_rating': 35.0,
#   'business_id': 500274,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '巧克力蛋糕', '烟熏三文鱼'],
#   'latitude': 31.227983,
#   'longitude': 121.52355,
#   'name': '汇海餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 245.0,
#   'avg_rating': 40.0,
#   'business_id': 500314,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['烤牛肉', '烤香蕉', '芝士小面包'],
#   'latitude': 31.21951,
#   'longitude': 121.47526,
#   'name': '拉蒂娜Latina(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 104.0,
#   'avg_rating': 40.0,
#   'business_id': 500336,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['乌梅汁', '婆婆蛋饺', '秘制牛肉'],
#   'latitude': 31.21063,
#   'longitude': 121.44784,
#   'name': '来福楼火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 120.0,
#   'avg_rating': 40.0,
#   'business_id': 500380,
#   'category': '韩国料理',
#   'city': '上海',
#   'cn_tag': ['海鲜葱饼', '烤五花肉', '石锅拌饭'],
#   'latitude': 31.195335,
#   'longitude': 121.39564,
#   'name': '陵水酒家(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 92.0,
#   'avg_rating': 35.0,
#   'business_id': 500387,
#   'category': '台湾菜',
#   'city': '上海',
#   'cn_tag': ['三杯鸡', '芒果冰沙', '菠萝油条虾'],
#   'latitude': 31.198942,
#   'longitude': 121.39248,
#   'name': '鹿港小镇(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 204.0,
#   'avg_rating': 45.0,
#   'business_id': 500412,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['杨枝甘露', '油爆虾', '石锅银雪鱼'],
#   'latitude': 31.202951,
#   'longitude': 121.40585,
#   'name': '扬子江万丽酒店满福楼酒家(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 387.0,
#   'avg_rating': 40.0,
#   'business_id': 500451,
#   'category': '西餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '牛排', '蛋白饼'],
#   'latitude': 31.234451,
#   'longitude': 121.49071,
#   'name': '米氏西餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 82.0,
#   'avg_rating': 30.0,
#   'business_id': 500453,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼'],
#   'latitude': 31.190521,
#   'longitude': 121.39423,
#   'name': '名都城俱乐部(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 660.0,
#   'avg_rating': 45.0,
#   'business_id': 500456,
#   'category': '本帮江浙菜',
#   'city': '上海',
#   'cn_tag': ['烤鳕鱼', '蟹粉鱼翅', '鹅肝'],
#   'latitude': 31.203217,
#   'longitude': 121.44718,
#   'name': '名轩(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 83.0,
#   'avg_rating': 35.0,
#   'business_id': 500460,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['烤羊排', '羊肉', '羊脊骨锅底'],
#   'latitude': 31.17439,
#   'longitude': 121.42925,
#   'name': '名羊天下(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 19.0,
#   'avg_rating': 30.0,
#   'business_id': 500501,
#   'category': '素菜',
#   'city': '上海',
#   'cn_tag': ['海棠糕', '素菜包', '香菇菜包'],
#   'latitude': 31.226406,
#   'longitude': 121.490974,
#   'name': '春风松月楼(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 67.0,
#   'avg_rating': 30.0,
#   'business_id': 500514,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['印度飞饼', '酸菜鱼锅底', '金针菇'],
#   'latitude': 31.270456,
#   'longitude': 121.480194,
#   'name': '谭氏火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 86.0,
#   'avg_rating': 35.0,
#   'business_id': 500613,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['沙茶酱', '肥牛', '骨头锅底'],
#   'latitude': 31.223858,
#   'longitude': 121.52413,
#   'name': '小城火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 82.0,
#   'avg_rating': 35.0,
#   'business_id': 500617,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['羊肉', '肥羊肉', '鸳鸯锅底'],
#   'latitude': 31.265312,
#   'longitude': 121.47951,
#   'name': '小肥羊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 82.0,
#   'avg_rating': 35.0,
#   'business_id': 500621,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['羊肉', '肥羊肉', '金针菇'],
#   'latitude': 31.189304,
#   'longitude': 121.43358,
#   'name': '小肥羊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 81.0,
#   'avg_rating': 35.0,
#   'business_id': 500622,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['羊肉', '肥羊肉', '金针菇'],
#   'latitude': 31.211143,
#   'longitude': 121.48249,
#   'name': '小肥羊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 116.0,
#   'avg_rating': 35.0,
#   'business_id': 500643,
#   'category': '贵州菜',
#   'city': '上海',
#   'cn_tag': ['小米渣', '盗汗鸡', '酸汤乌江鱼'],
#   'latitude': 31.229713,
#   'longitude': 121.51152,
#   'name': '黔香阁(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 194.0,
#   'avg_rating': 40.0,
#   'business_id': 500658,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '刺生拼盘', '烤鳗鱼'],
#   'latitude': 31.210505,
#   'longitude': 121.40079,
#   'name': '太郎(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 77.0,
#   'avg_rating': 35.0,
#   'business_id': 500668,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['骨头王锅底', '骨头砂锅', '骨头锅'],
#   'latitude': 31.19708,
#   'longitude': 121.44549,
#   'name': '三人行骨头王火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 69.0,
#   'avg_rating': 30.0,
#   'business_id': 500669,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['剁椒鱼头', '干锅牛蛙', '酸豆角炒腊肉'],
#   'latitude': 31.19435,
#   'longitude': 121.41823,
#   'name': '芙蓉阁(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 182.0,
#   'avg_rating': 30.0,
#   'business_id': 500674,
#   'category': '西餐',
#   'city': '上海',
#   'cn_tag': ['可办大型宴会', '商务宴请', '有露天位'],
#   'latitude': 31.189074,
#   'longitude': 121.36058,
#   'name': '沙逊花园(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 200.0,
#   'avg_rating': 35.0,
#   'business_id': 500712,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '甜品', '甜点'],
#   'latitude': 31.22956,
#   'longitude': 121.52166,
#   'name': '锦江汤臣洲际大酒店壹阶层餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 129.0,
#   'avg_rating': 40.0,
#   'business_id': 500720,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['清炒虾仁', '灌汤虾球', '片皮鸭'],
#   'latitude': 31.292994,
#   'longitude': 121.51784,
#   'name': '星晨酒店(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 239.0,
#   'avg_rating': 40.0,
#   'business_id': 500725,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '海鲜', '甜品'],
#   'latitude': 31.239433,
#   'longitude': 121.52472,
#   'name': '旋宫50旋转餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 131.0,
#   'avg_rating': 30.0,
#   'business_id': 500737,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['生煎', '虾饺皇', '金牌吊烧鸡'],
#   'latitude': 31.194963,
#   'longitude': 121.422775,
#   'name': '阳光名邸大酒店(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 82.0,
#   'avg_rating': 35.0,
#   'business_id': 500792,
#   'category': '素菜',
#   'city': '上海',
#   'cn_tag': ['叉烧酥', '长相思', '黑椒牛排'],
#   'latitude': 31.2227,
#   'longitude': 121.47573,
#   'name': '枣子树(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 65.0,
#   'avg_rating': 35.0,
#   'business_id': 500820,
#   'category': '韩国料理',
#   'city': '上海',
#   'cn_tag': ['海鲜饼', '烤五花肉', '石锅拌饭'],
#   'latitude': 31.220474,
#   'longitude': 121.52843,
#   'name': '云龙韩国料理(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 56.0,
#   'avg_rating': 30.0,
#   'business_id': 500829,
#   'category': '西餐',
#   'city': '上海',
#   'cn_tag': ['炸猪排', '罗宋汤', '葡国鸡'],
#   'latitude': 31.19889,
#   'longitude': 121.43882,
#   'name': '新利查西菜馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 91.0,
#   'avg_rating': 35.0,
#   'business_id': 500835,
#   'category': '台湾菜',
#   'city': '上海',
#   'cn_tag': ['三杯鸡', '花生冰沙', '菠萝油条虾'],
#   'latitude': 31.19523,
#   'longitude': 121.39695,
#   'name': '鹿港小镇(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 84.0,
#   'avg_rating': 35.0,
#   'business_id': 500870,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['羊肉', '肥羊肉', '金针菇'],
#   'latitude': 31.214891,
#   'longitude': 121.52878,
#   'name': '小肥羊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 218.0,
#   'avg_rating': 40.0,
#   'business_id': 500883,
#   'category': '东南亚菜',
#   'city': '上海',
#   'cn_tag': ['印尼炒饭', '咖喱蟹', '烤银鳕鱼'],
#   'latitude': 31.22193,
#   'longitude': 121.44663,
#   'name': '巴厘岛(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 90.0,
#   'avg_rating': 35.0,
#   'business_id': 500889,
#   'category': '新疆菜',
#   'city': '上海',
#   'cn_tag': ['大盘鸡', '奶茶', '羊肉串'],
#   'latitude': 31.188885,
#   'longitude': 121.42972,
#   'name': '新疆风味饭馆维吾尔餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 81.0,
#   'avg_rating': 35.0,
#   'business_id': 500892,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['干锅牛蛙', '干锅茶树菇', '鸳鸯鱼头'],
#   'latitude': 31.22447,
#   'longitude': 121.5226,
#   'name': '望湘园(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 55.0,
#   'avg_rating': 30.0,
#   'business_id': 500894,
#   'category': '新疆菜',
#   'city': '上海',
#   'cn_tag': ['刀削面', '手抓羊肉', '烩刀削', '刀削面', '手抓羊肉', '烩刀削'],
#   'latitude': 31.234947,
#   'longitude': 121.52932,
#   'name': '稻草屋(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 55.0,
#   'avg_rating': 30.0,
#   'business_id': 500894,
#   'category': '西北菜',
#   'city': '上海',
#   'cn_tag': ['刀削面', '手抓羊肉', '烩刀削', '刀削面', '手抓羊肉', '烩刀削'],
#   'latitude': 31.234947,
#   'longitude': 121.52932,
#   'name': '稻草屋(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 61.0,
#   'avg_rating': 30.0,
#   'business_id': 500899,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['沙茶酱', '骨头砂锅', '骨头锅底'],
#   'latitude': 31.246698,
#   'longitude': 121.57224,
#   'name': '仁义火锅城(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 116.0,
#   'avg_rating': 40.0,
#   'business_id': 500973,
#   'category': '东南亚菜',
#   'city': '上海',
#   'cn_tag': ['尼泊尔鸡翅', '芝士球', '酸奶'],
#   'latitude': 31.219336,
#   'longitude': 121.45018,
#   'name': 'Nepali Kitchen(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 147.0,
#   'avg_rating': 40.0,
#   'business_id': 500980,
#   'category': '西餐',
#   'city': '上海',
#   'cn_tag': ['提拉米苏', '芝士蛋糕', '银鳕鱼'],
#   'latitude': 31.208494,
#   'longitude': 121.44979,
#   'name': '藏珑坊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 103.0,
#   'avg_rating': 35.0,
#   'business_id': 500988,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['烧味拼盘', '盐插虾', '芥兰牛肉'],
#   'latitude': 31.20281,
#   'longitude': 121.44484,
#   'name': '衡山小馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 148.0,
#   'avg_rating': 40.0,
#   'business_id': 500990,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['口水鸡', '毛血旺', '滚石牛肉'],
#   'latitude': 31.209076,
#   'longitude': 121.44811,
#   'name': '品川(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 42.0,
#   'avg_rating': 30.0,
#   'business_id': 500996,
#   'category': '台湾菜',
#   'city': '上海',
#   'cn_tag': ['大饼卷肉', '小米粥', '牛肉馅饼'],
#   'latitude': 31.182596,
#   'longitude': 121.37451,
#   'name': '楚楚园馅饼粥(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 170.0,
#   'avg_rating': 35.0,
#   'business_id': 501051,
#   'category': '本帮江浙菜',
#   'city': '上海',
#   'cn_tag': ['德国咸猪手', '黄啤', '黑啤', '德国咸猪手', '黄啤', '黑啤'],
#   'latitude': 31.236628,
#   'longitude': 121.48908,
#   'name': '外滩啤酒总汇(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 170.0,
#   'avg_rating': 35.0,
#   'business_id': 501051,
#   'category': '西餐',
#   'city': '上海',
#   'cn_tag': ['德国咸猪手', '黄啤', '黑啤', '德国咸猪手', '黄啤', '黑啤'],
#   'latitude': 31.236628,
#   'longitude': 121.48908,
#   'name': '外滩啤酒总汇(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 477.0,
#   'avg_rating': 40.0,
#   'business_id': 501060,
#   'category': '西餐',
#   'city': '上海',
#   'cn_tag': ['海鲜拼盘', '烤牛排', '鹅肝'],
#   'latitude': 31.23504,
#   'longitude': 121.50581,
#   'name': '食在56美式烧烤餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 57.0,
#   'avg_rating': 35.0,
#   'business_id': 501063,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['沙姜鸡', '烧鹅', '蜜汁叉烧'],
#   'latitude': 31.211218,
#   'longitude': 121.45069,
#   'name': '博多新记(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 56.0,
#   'avg_rating': 30.0,
#   'business_id': 501064,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['沙姜鸡', '烧鹅', '蜜汁叉烧'],
#   'latitude': 31.217655,
#   'longitude': 121.45505,
#   'name': '博多新记(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 91.0,
#   'avg_rating': 35.0,
#   'business_id': 501071,
#   'category': '西餐',
#   'city': '上海',
#   'cn_tag': ['啤酒'],
#   'latitude': 31.235678,
#   'longitude': 121.480865,
#   'name': '505啤酒屋(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 73.0,
#   'avg_rating': 35.0,
#   'business_id': 501073,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['钵钵鸡', '骨头砂锅', '骨头锅'],
#   'latitude': 31.218082,
#   'longitude': 121.43412,
#   'name': '三人行骨头王火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 80.0,
#   'avg_rating': 40.0,
#   'business_id': 501074,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['羊肉', '肥羊肉', '金针菇'],
#   'latitude': 31.289066,
#   'longitude': 121.52036,
#   'name': '小肥羊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 68.0,
#   'avg_rating': 30.0,
#   'business_id': 501076,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['羊肉', '肥羊肉', '金针菇'],
#   'latitude': 31.004877,
#   'longitude': 121.232765,
#   'name': '小肥羊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 82.0,
#   'avg_rating': 30.0,
#   'business_id': 501077,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['剁椒鱼头', '孜然排骨', '酸豆角炒肉末'],
#   'latitude': 31.20591,
#   'longitude': 121.38886,
#   'name': '滴水洞湘菜馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 86.0,
#   'avg_rating': 35.0,
#   'business_id': 501078,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['剁椒鱼头', '干锅茶树菇', '手撕包菜'],
#   'latitude': 31.186256,
#   'longitude': 121.43518,
#   'name': '洞庭春(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 73.0,
#   'avg_rating': 35.0,
#   'business_id': 501100,
#   'category': '东北菜',
#   'city': '上海',
#   'cn_tag': ['地三鲜', '小鸡炖蘑菇', '酱骨头'],
#   'latitude': 31.20963,
#   'longitude': 121.429245,
#   'name': '东北人(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 93.0,
#   'avg_rating': 40.0,
#   'business_id': 501135,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['小龙虾', '牛蛙', '香辣蟹'],
#   'latitude': 31.22944,
#   'longitude': 121.42792,
#   'name': '宋记香辣蟹(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 64.0,
#   'avg_rating': 30.0,
#   'business_id': 501144,
#   'category': '台湾菜',
#   'city': '上海',
#   'cn_tag': ['红豆冰', '红豆冰沙', '肉燥饭'],
#   'latitude': 31.22917,
#   'longitude': 121.458015,
#   'name': '一茶一坐(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 198.0,
#   'avg_rating': 35.0,
#   'business_id': 501152,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '批萨'],
#   'latitude': 31.22376,
#   'longitude': 121.52824,
#   'name': '红塔豪华精选酒店圣思园餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 161.0,
#   'avg_rating': 40.0,
#   'business_id': 501213,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['乳鸽', '榴莲酥', '虾饺'],
#   'latitude': 31.197256,
#   'longitude': 121.39195,
#   'name': '海逸海鲜(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 77.0,
#   'avg_rating': 30.0,
#   'business_id': 501272,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['沙茶酱', '肥牛肉', '骨头锅'],
#   'latitude': 31.211567,
#   'longitude': 121.5247,
#   'name': '陌生人火锅餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 124.0,
#   'avg_rating': 35.0,
#   'business_id': 501282,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '冰激凌', '甜点'],
#   'latitude': 31.181475,
#   'longitude': 121.44077,
#   'name': '富豪东亚酒店咖啡厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 92.0,
#   'avg_rating': 35.0,
#   'business_id': 501349,
#   'category': '台湾菜',
#   'city': '上海',
#   'cn_tag': ['三杯鸡', '咖喱牛腩', '花生冰沙'],
#   'latitude': 31.199877,
#   'longitude': 121.40003,
#   'name': '祖祖餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 45.0,
#   'avg_rating': 30.0,
#   'business_id': 501379,
#   'category': '东北菜',
#   'city': '上海',
#   'cn_tag': ['酱骨头', '饺子', '麻酱拉皮'],
#   'latitude': 31.205067,
#   'longitude': 121.44006,
#   'name': '东北四季饺子王(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 122.0,
#   'avg_rating': 40.0,
#   'business_id': 501386,
#   'category': '西餐',
#   'city': '上海',
#   'cn_tag': ['布丁', '烩羊肉', '馅饼'],
#   'latitude': 31.191685,
#   'longitude': 121.38951,
#   'name': '墨西哥灵得餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 22.0,
#   'avg_rating': 35.0,
#   'business_id': 501404,
#   'category': '素菜',
#   'city': '上海',
#   'cn_tag': ['双菇狮子头面', '双菇面', '罗汉什锦面'],
#   'latitude': 31.241564,
#   'longitude': 121.44563,
#   'name': '玉佛寺素斋(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 83.0,
#   'avg_rating': 30.0,
#   'business_id': 501442,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['豆腐', '鸭血', '麻辣锅底'],
#   'latitude': 31.211956,
#   'longitude': 121.52453,
#   'name': '吴记老锅底麻辣火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 72.0,
#   'avg_rating': 30.0,
#   'business_id': 501524,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['全鱼锅', '酸菜鱼锅底', '鱼丸'],
#   'latitude': 31.206509,
#   'longitude': 121.38752,
#   'name': '世亮火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 146.0,
#   'avg_rating': 40.0,
#   'business_id': 501581,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['焦糖布丁', '牛排', '羊排'],
#   'latitude': 31.235077,
#   'longitude': 121.480385,
#   'name': '王宝和咖啡厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 191.0,
#   'avg_rating': 40.0,
#   'business_id': 501583,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['甜点', '生鱼片', '鹅肝'],
#   'latitude': 31.219954,
#   'longitude': 121.45978,
#   'name': '玫瑰咖啡厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 76.0,
#   'avg_rating': 40.0,
#   'business_id': 501609,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['毛肚', '金针菇', '鸭肠'],
#   'latitude': 31.234856,
#   'longitude': 121.43984,
#   'name': '重庆小天鹅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 56.0,
#   'avg_rating': 40.0,
#   'business_id': 501682,
#   'category': '东北菜',
#   'city': '上海',
#   'cn_tag': ['地三鲜', '豆角炖排骨', '锅包肉'],
#   'latitude': 31.248772,
#   'longitude': 121.41428,
#   'name': '月季园(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 78.0,
#   'avg_rating': 35.0,
#   'business_id': 501699,
#   'category': '韩国料理',
#   'city': '上海',
#   'cn_tag': ['炒年糕', '烤五花肉', '石锅拌饭'],
#   'latitude': 31.301233,
#   'longitude': 121.49418,
#   'name': '长白山韩国烧烤店(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 53.0,
#   'avg_rating': 30.0,
#   'business_id': 501743,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['剁椒鱼头', '孜然排骨', '酸豆角炒鸡珍'],
#   'latitude': 31.159286,
#   'longitude': 121.34317,
#   'name': '湘水洞(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 80.0,
#   'avg_rating': 35.0,
#   'business_id': 501760,
#   'category': '新疆菜',
#   'city': '上海',
#   'cn_tag': ['大盘鸡', '羊肉串', '酸奶', '大盘鸡', '羊肉串', '酸奶'],
#   'latitude': 31.172712,
#   'longitude': 121.42696,
#   'name': '耶里夏丽新疆餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 80.0,
#   'avg_rating': 35.0,
#   'business_id': 501760,
#   'category': '清真菜',
#   'city': '上海',
#   'cn_tag': ['大盘鸡', '羊肉串', '酸奶', '大盘鸡', '羊肉串', '酸奶'],
#   'latitude': 31.172712,
#   'longitude': 121.42696,
#   'name': '耶里夏丽新疆餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 57.0,
#   'avg_rating': 30.0,
#   'business_id': 501793,
#   'category': '新疆菜',
#   'city': '上海',
#   'cn_tag': ['口水鸡', '辣子鸡', '酸菜鱼'],
#   'latitude': 31.260258,
#   'longitude': 121.49887,
#   'name': '虹临鲜鸡鲜鱼坊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 46.0,
#   'avg_rating': 35.0,
#   'business_id': 501806,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['干锅牛蛙', '蛋包饭', '鸡翅'],
#   'latitude': 31.25131,
#   'longitude': 121.48269,
#   'name': '井上蛙干锅一绝(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 191.0,
#   'avg_rating': 35.0,
#   'business_id': 501841,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '冰淇淋', '甜品'],
#   'latitude': 31.191498,
#   'longitude': 121.37703,
#   'name': '万豪虹桥咖啡厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 85.0,
#   'avg_rating': 30.0,
#   'business_id': 501851,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['羊肉', '自制羊肉调料', '骨头锅底'],
#   'latitude': 31.259047,
#   'longitude': 121.50385,
#   'name': '旺旺火锅楼(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 36.0,
#   'avg_rating': 30.0,
#   'business_id': 501879,
#   'category': '台湾菜',
#   'city': '上海',
#   'cn_tag': ['小米粥', '牛肉馅饼', '皮蛋瘦肉粥'],
#   'latitude': 31.222902,
#   'longitude': 121.47583,
#   'name': '楚楚园馅饼粥(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 63.0,
#   'avg_rating': 30.0,
#   'business_id': 501896,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['包心贡丸', '手打鲜虾丸', '骨头锅'],
#   'latitude': 31.003466,
#   'longitude': 121.41719,
#   'name': '部落情(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 151.0,
#   'avg_rating': 20.0,
#   'business_id': 501908,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['生蚝', '色拉', '色拉球'],
#   'latitude': 31.244497,
#   'longitude': 121.49157,
#   'name': '乐帕全景餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 66.0,
#   'avg_rating': 40.0,
#   'business_id': 501921,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['四川小辣椒火锅', '土豆片', '青笋'],
#   'latitude': 31.2512,
#   'longitude': 121.48644,
#   'name': '小辣椒火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 54.0,
#   'avg_rating': 35.0,
#   'business_id': 501927,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['双椒鱼头', '酸豆角炒鸡胗', '酸辣土豆丝'],
#   'latitude': 31.273752,
#   'longitude': 121.47973,
#   'name': '果园(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 57.0,
#   'avg_rating': 30.0,
#   'business_id': 501965,
#   'category': '台湾菜',
#   'city': '上海',
#   'cn_tag': ['三杯鸡', '九层塔花枝头', '鲁肉饭'],
#   'latitude': 31.205795,
#   'longitude': 121.40454,
#   'name': '鼎炉(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 85.0,
#   'avg_rating': 30.0,
#   'business_id': 501981,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['羊肉', '肥羊肉', '金针菇'],
#   'latitude': 31.23971,
#   'longitude': 121.40465,
#   'name': '小肥羊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 141.0,
#   'avg_rating': 40.0,
#   'business_id': 502019,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['咖喱锅底', '手工丸子', '手工虾丸'],
#   'latitude': 31.218945,
#   'longitude': 121.44653,
#   'name': '锅比盆大(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 41.0,
#   'avg_rating': 30.0,
#   'business_id': 502020,
#   'category': '东北菜',
#   'city': '上海',
#   'cn_tag': ['地三鲜', '小鸡炖蘑菇', '锅包肉'],
#   'latitude': 31.308273,
#   'longitude': 121.5041,
#   'name': '哈尔滨风味小吃(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 56.0,
#   'avg_rating': 30.0,
#   'business_id': 502059,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['干锅基围虾', '酸菜鱼锅底', '骨头锅'],
#   'latitude': 31.197536,
#   'longitude': 121.68935,
#   'name': '谭火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 99.0,
#   'avg_rating': 30.0,
#   'business_id': 502108,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['椒盐大王蛇', '水煮鱼', '烤羊排'],
#   'latitude': 31.205696,
#   'longitude': 121.47168,
#   'name': '小花牛(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 61.0,
#   'avg_rating': 30.0,
#   'business_id': 502166,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['包心贡丸', '骨头锅底', '鱼豆腐'],
#   'latitude': 31.235157,
#   'longitude': 121.52072,
#   'name': '小城火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 37.0,
#   'avg_rating': 35.0,
#   'business_id': 502170,
#   'category': '西北菜',
#   'city': '上海',
#   'cn_tag': ['牛肉菜夹饼', '肉夹馍', '蕨根粉'],
#   'latitude': 31.22688,
#   'longitude': 121.44678,
#   'name': '敦煌小亭(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 64.0,
#   'avg_rating': 20.0,
#   'business_id': 502229,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['酸菜鱼锅底', '顶级牛肉', '骨头锅底'],
#   'latitude': 31.211645,
#   'longitude': 121.52589,
#   'name': '胡乔火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 787.0,
#   'avg_rating': 45.0,
#   'business_id': 502331,
#   'category': '本帮江浙菜',
#   'city': '上海',
#   'cn_tag': ['烤银鳕鱼', '蟹粉鱼翅', '鱼翅'],
#   'latitude': 31.231123,
#   'longitude': 121.51862,
#   'name': '名轩(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 233.0,
#   'avg_rating': 30.0,
#   'business_id': 502333,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '哈根达斯', '生鱼片'],
#   'latitude': 31.22823,
#   'longitude': 121.455956,
#   'name': '金钱豹国际美食百汇(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 125.0,
#   'avg_rating': 30.0,
#   'business_id': 502343,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '水果', '羊排'],
#   'latitude': 31.246584,
#   'longitude': 121.45484,
#   'name': '长城假日酒店天使咖啡厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 101.0,
#   'avg_rating': 35.0,
#   'business_id': 502409,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['凤爪', '天下第一包', '虾饺皇'],
#   'latitude': 31.174894,
#   'longitude': 121.42873,
#   'name': '一品粤珍(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 71.0,
#   'avg_rating': 35.0,
#   'business_id': 502456,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['豆腐', '鸭血', '麻辣锅底'],
#   'latitude': 31.245707,
#   'longitude': 121.48746,
#   'name': '吴记老锅底麻辣火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 51.0,
#   'avg_rating': 30.0,
#   'business_id': 502499,
#   'category': '韩国料理',
#   'city': '上海',
#   'cn_tag': ['炒年糕', '烤五花肉', '石锅拌饭'],
#   'latitude': 31.301514,
#   'longitude': 121.50458,
#   'name': '大学路(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 83.0,
#   'avg_rating': 35.0,
#   'business_id': 502507,
#   'category': '素菜',
#   'city': '上海',
#   'cn_tag': ['叉烧酥', '长相思', '黑椒素排'],
#   'latitude': 31.229855,
#   'longitude': 121.456825,
#   'name': '枣子树(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 62.0,
#   'avg_rating': 30.0,
#   'business_id': 502509,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['干锅牛蛙', '水煮鱼', '盐锔鸡'],
#   'latitude': 31.21886,
#   'longitude': 121.44879,
#   'name': '湾仔(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 180.0,
#   'avg_rating': 40.0,
#   'business_id': 502522,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '冰淇淋', '甜点'],
#   'latitude': 31.234364,
#   'longitude': 121.47951,
#   'name': '豪生咖啡厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 300.0,
#   'avg_rating': 40.0,
#   'business_id': 502523,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '甜品', '生蚝'],
#   'latitude': 31.232384,
#   'longitude': 121.48686,
#   'name': '威斯汀舞台餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 283.0,
#   'avg_rating': 40.0,
#   'business_id': 502524,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '生蚝', '鹅肝'],
#   'latitude': 31.203644,
#   'longitude': 121.40555,
#   'name': '虹桥喜来登Cafe Bistro餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 123.0,
#   'avg_rating': 30.0,
#   'business_id': 502525,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '冰激凌草香口味', '面包'],
#   'latitude': 31.237982,
#   'longitude': 121.4334,
#   'name': '古井假日酒店霖阁西餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 185.0,
#   'avg_rating': 35.0,
#   'business_id': 502532,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['水煮鱼', '江石滚肥牛', '麻酱油麦菜'],
#   'latitude': 31.23733,
#   'longitude': 121.49998,
#   'name': '俏江南(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 9.0,
#   'avg_rating': 35.0,
#   'business_id': 502578,
#   'category': '烧烤',
#   'city': '上海',
#   'cn_tag': ['牛筋', '羊肉', '金针菇'],
#   'latitude': 31.211693,
#   'longitude': 121.52788,
#   'name': '老姜烧烤(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 47.0,
#   'avg_rating': 30.0,
#   'business_id': 502636,
#   'category': '东北菜',
#   'city': '上海',
#   'cn_tag': ['东北大拉皮', '地三鲜', '锅包肉'],
#   'latitude': 31.209986,
#   'longitude': 121.40164,
#   'name': '东北四季饺子王(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 72.0,
#   'avg_rating': 35.0,
#   'business_id': 502654,
#   'category': '东北菜',
#   'city': '上海',
#   'cn_tag': ['大拉皮', '小鸡炖蘑菇', '手工水饺'],
#   'latitude': 31.210808,
#   'longitude': 121.391045,
#   'name': '东北人(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 63.0,
#   'avg_rating': 30.0,
#   'business_id': 502677,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['干锅牛蛙', '干锅脆骨', '湘情鱼头王'],
#   'latitude': 31.24029,
#   'longitude': 121.52816,
#   'name': '湘情酒店(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 228.0,
#   'avg_rating': 35.0,
#   'business_id': 502678,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '烟熏三文鱼', '甜点'],
#   'latitude': 31.219545,
#   'longitude': 121.4457,
#   'name': '希尔顿连天阁(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 141.0,
#   'avg_rating': 40.0,
#   'business_id': 502715,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['榴莲酥', '炭烧猪颈肉', '鲍汁萝卜'],
#   'latitude': 31.173286,
#   'longitude': 121.37611,
#   'name': '添彩酒楼(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 61.0,
#   'avg_rating': 40.0,
#   'business_id': 502717,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['干锅鸭头', '香辣蟹', '骨头锅底'],
#   'latitude': 31.114986,
#   'longitude': 121.577515,
#   'name': '蜀华楼(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 192.0,
#   'avg_rating': 45.0,
#   'business_id': 502824,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '海鲜', '甜点'],
#   'latitude': 31.209911,
#   'longitude': 121.434555,
#   'name': '兴国宾馆香樟园西餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 104.0,
#   'avg_rating': 35.0,
#   'business_id': 502893,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['手打墨鱼丸', '甘蔗马蹄汁', '肥牛'],
#   'latitude': 31.20347,
#   'longitude': 121.47038,
#   'name': '一哥肥牛火锅海鲜酒家(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 42.0,
#   'avg_rating': 35.0,
#   'business_id': 502902,
#   'category': '韩国料理',
#   'city': '上海',
#   'cn_tag': ['炒糕条', '烤金针菇', '石锅拌饭'],
#   'latitude': 31.2961,
#   'longitude': 121.50996,
#   'name': '土大力(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 102.0,
#   'avg_rating': 35.0,
#   'business_id': 502904,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['千岛湖的鱼头', '潮州鱼丸', '鱼头'],
#   'latitude': 31.206692,
#   'longitude': 121.397316,
#   'name': '来来火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 39.0,
#   'avg_rating': 35.0,
#   'business_id': 502967,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['口水鸡', '瓦片鱼', '跳水牛蛙'],
#   'latitude': 31.247753,
#   'longitude': 121.49199,
#   'name': '瓦片鱼特色川味馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 64.0,
#   'avg_rating': 30.0,
#   'business_id': 502988,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['原味汤骨沙锅', '椒盐芋艿', '炝虾'],
#   'latitude': 31.272234,
#   'longitude': 121.50465,
#   'name': '菽心阁(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 44.0,
#   'avg_rating': 30.0,
#   'business_id': 503004,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['剁椒鱼头', '玉米酪'],
#   'latitude': 31.26205,
#   'longitude': 121.48967,
#   'name': '湘菜馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 60.0,
#   'avg_rating': 30.0,
#   'business_id': 503016,
#   'category': '韩国料理',
#   'city': '上海',
#   'cn_tag': ['炒年糕', '烤五花肉', '石锅拌饭'],
#   'latitude': 31.199718,
#   'longitude': 121.55444,
#   'name': '真炉碳烤(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 195.0,
#   'avg_rating': 40.0,
#   'business_id': 503021,
#   'category': '西餐',
#   'city': '上海',
#   'cn_tag': ['巧克力蛋糕', '牛排', '红酒'],
#   'latitude': 31.234167,
#   'longitude': 121.49086,
#   'name': '新视角餐厅酒廊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 84.0,
#   'avg_rating': 35.0,
#   'business_id': 503064,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['豆腐', '酸梅汤', '鸭血'],
#   'latitude': 31.184998,
#   'longitude': 121.43553,
#   'name': '吴记老锅底麻辣火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 88.0,
#   'avg_rating': 35.0,
#   'business_id': 503065,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['豆腐', '鸭血', '麻辣锅底'],
#   'latitude': 31.191067,
#   'longitude': 121.44209,
#   'name': '吴记老锅底麻辣火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 23.0,
#   'avg_rating': 30.0,
#   'business_id': 503068,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['叉烧', '烧鸭', '烧鹅'],
#   'latitude': 31.22111,
#   'longitude': 121.43703,
#   'name': '福临港式烧味馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 47.0,
#   'avg_rating': 30.0,
#   'business_id': 503082,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['剁椒鱼头', '红烧肉', '臭豆腐'],
#   'latitude': 31.187346,
#   'longitude': 121.457985,
#   'name': '湖南正宗乡土风味(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 58.0,
#   'avg_rating': 30.0,
#   'business_id': 503087,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['水煮鱼', '沸腾鱼', '钵钵鸡'],
#   'latitude': 31.012638,
#   'longitude': 121.414246,
#   'name': '龙虾馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 45.0,
#   'avg_rating': 35.0,
#   'business_id': 503138,
#   'category': '韩国料理',
#   'city': '上海',
#   'cn_tag': ['五花肉炒章鱼', '打糕', '石锅拌饭'],
#   'latitude': 31.212812,
#   'longitude': 121.51824,
#   'name': '江村寨子韩国料理(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 153.0,
#   'avg_rating': 30.0,
#   'business_id': 503139,
#   'category': '西餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '小青龙', '巧克力慕斯'],
#   'latitude': 31.222692,
#   'longitude': 121.45707,
#   'name': '维也纳西餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 18.0,
#   'avg_rating': 30.0,
#   'business_id': 503145,
#   'category': '新疆菜',
#   'city': '上海',
#   'cn_tag': ['牛肉锅贴', '羊肉串', '羊肉汤'],
#   'latitude': 31.23153,
#   'longitude': 121.48059,
#   'name': '穆斯林饮食店(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 46.0,
#   'avg_rating': 30.0,
#   'business_id': 503151,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['烤羊肉', '烤羊肉串', '香肠'],
#   'latitude': 31.201233,
#   'longitude': 121.45409,
#   'name': '半岛餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 70.0,
#   'avg_rating': 35.0,
#   'business_id': 503157,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['剁椒鱼头', '手撕包菜', '鸳鸯鱼头'],
#   'latitude': 31.209826,
#   'longitude': 121.460106,
#   'name': '湘泉乡村土菜馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 76.0,
#   'avg_rating': 35.0,
#   'business_id': 503158,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['土匪鸭', '手撕包菜', '鸳鸯鱼头'],
#   'latitude': 31.187056,
#   'longitude': 121.373535,
#   'name': '湘泉乡村土菜馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 40.0,
#   'avg_rating': 30.0,
#   'business_id': 503178,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['口水鸡', '干锅鸡', '水煮鱼'],
#   'latitude': 31.233765,
#   'longitude': 121.40818,
#   'name': '真味川菜(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 67.0,
#   'avg_rating': 30.0,
#   'business_id': 503180,
#   'category': '贵州菜',
#   'city': '上海',
#   'cn_tag': ['干锅鸡', '苗家干锅鸡', '走水乌江鱼'],
#   'latitude': 31.235836,
#   'longitude': 121.481415,
#   'name': '干锅居(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 103.0,
#   'avg_rating': 40.0,
#   'business_id': 503204,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['百灵菇炒虾仁', '虾饺', '鹅肝酱牛肉'],
#   'latitude': 31.223852,
#   'longitude': 121.55225,
#   'name': '万丽轩(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 163.0,
#   'avg_rating': 40.0,
#   'business_id': 503205,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '甜品', '羊排'],
#   'latitude': 31.223766,
#   'longitude': 121.55262,
#   'name': '淳大万丽咖啡厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 205.0,
#   'avg_rating': 40.0,
#   'business_id': 503206,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['北菇滑鸡粥', '叉烧肠粉', '虾饺'],
#   'latitude': 31.203594,
#   'longitude': 121.40553,
#   'name': '翡翠园中餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 124.0,
#   'avg_rating': 35.0,
#   'business_id': 503208,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['云吞面', '黄鱼面', '黑胡椒围虾煲'],
#   'latitude': 31.202951,
#   'longitude': 121.40585,
#   'name': '翠竹小馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 214.0,
#   'avg_rating': 35.0,
#   'business_id': 503210,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '甜点', '龙虾'],
#   'latitude': 31.21111,
#   'longitude': 121.53398,
#   'name': '东锦江希尔顿逸林Grand Cafe(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 276.0,
#   'avg_rating': 40.0,
#   'business_id': 503215,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '地中海帝王蟹', '甜品'],
#   'latitude': 31.230473,
#   'longitude': 121.47002,
#   'name': 'JW万豪咖啡厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 168.0,
#   'avg_rating': 35.0,
#   'business_id': 503229,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '甜品', '羊排'],
#   'latitude': 31.189669,
#   'longitude': 121.4379,
#   'name': '建国宾馆葵园自助晚餐(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 57.0,
#   'avg_rating': 30.0,
#   'business_id': 503271,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['潮州骨头锅', '牛百叶', '香辣蟹'],
#   'latitude': 31.179857,
#   'longitude': 121.39244,
#   'name': '日日旺火锅城(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 352.0,
#   'avg_rating': 40.0,
#   'business_id': 503292,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['烟熏三文鱼', '甜品', '蟹脚'],
#   'latitude': 31.23488,
#   'longitude': 121.5056,
#   'name': '上海金茂君悦咖啡厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 195.0,
#   'avg_rating': 30.0,
#   'business_id': 503304,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['小羊排', '烟熏三文鱼', '牛仔骨'],
#   'latitude': 31.202522,
#   'longitude': 121.39442,
#   'name': '棕榈岛咖啡厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 70.0,
#   'avg_rating': 30.0,
#   'business_id': 503340,
#   'category': '贵州菜',
#   'city': '上海',
#   'cn_tag': ['烤鱼', '酸汤鱼'],
#   'latitude': 31.174746,
#   'longitude': 121.43508,
#   'name': '黔锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 65.0,
#   'avg_rating': 30.0,
#   'business_id': 503393,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['口水鸡', '沸腾鱼', '石烤虾'],
#   'latitude': 31.28646,
#   'longitude': 121.49345,
#   'name': '蜀国川菜(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 72.0,
#   'avg_rating': 30.0,
#   'business_id': 503397,
#   'category': '贵州菜',
#   'city': '上海',
#   'cn_tag': ['干锅鸡', '水煮乌江鱼', '茶树菇干锅鸡'],
#   'latitude': 31.22588,
#   'longitude': 121.52719,
#   'name': '干锅居(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 98.0,
#   'avg_rating': 35.0,
#   'business_id': 503405,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['剁椒鱼头', '孜然排骨', '酸豆角炒肉末'],
#   'latitude': 31.208344,
#   'longitude': 121.45095,
#   'name': '滴水洞(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 146.0,
#   'avg_rating': 40.0,
#   'business_id': 503452,
#   'category': '西餐',
#   'city': '上海',
#   'cn_tag': ['土豆泥', '猪肘', '黑啤'],
#   'latitude': 31.191484,
#   'longitude': 121.38778,
#   'name': '德国乡村西餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 43.0,
#   'avg_rating': 30.0,
#   'business_id': 503464,
#   'category': '烧烤',
#   'city': '上海',
#   'cn_tag': ['羊肉串', '脆骨', '鸡翅'],
#   'latitude': 31.233643,
#   'longitude': 121.51744,
#   'name': '修记烧烤(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 94.0,
#   'avg_rating': 35.0,
#   'business_id': 503477,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['墨鱼仔煲', '酥皮汤圆', '黑椒牛仔骨'],
#   'latitude': 31.212553,
#   'longitude': 121.48887,
#   'name': '生活时尚大酒店(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 49.0,
#   'avg_rating': 30.0,
#   'business_id': 503492,
#   'category': '新疆菜',
#   'city': '上海',
#   'cn_tag': ['大盘鸡', '烤包子', '羊肉串'],
#   'latitude': 31.266052,
#   'longitude': 121.480316,
#   'name': '怡妮新疆风味(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 47.0,
#   'avg_rating': 30.0,
#   'business_id': 503524,
#   'category': '东北菜',
#   'city': '上海',
#   'cn_tag': ['酱大骨头', '酸菜猪肉炖粉条', '饺子'],
#   'latitude': 31.211773,
#   'longitude': 121.52577,
#   'name': '鹤乡东北菜(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 97.0,
#   'avg_rating': 35.0,
#   'business_id': 503547,
#   'category': '台湾菜',
#   'city': '上海',
#   'cn_tag': ['三杯鸡', '红豆糕', '马桥豆干土鸡锅'],
#   'latitude': 31.166311,
#   'longitude': 121.35721,
#   'name': '龙宴楼中餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 213.0,
#   'avg_rating': 40.0,
#   'business_id': 503564,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['东星斑', '凤爪', '天下第一包'],
#   'latitude': 31.23874,
#   'longitude': 121.5252,
#   'name': '东方海港大酒店(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 174.0,
#   'avg_rating': 40.0,
#   'business_id': 503601,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['宫爆鸡丁', '红马蹄珍珠椰露', '虾仁'],
#   'latitude': 31.232384,
#   'longitude': 121.48686,
#   'name': '威斯汀水晶苑中餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 254.0,
#   'avg_rating': 40.0,
#   'business_id': 503622,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '提拉米苏', '甜品'],
#   'latitude': 31.227274,
#   'longitude': 121.46236,
#   'name': '四季酒店咖啡厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 123.0,
#   'avg_rating': 30.0,
#   'business_id': 503623,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['泰式咖喱蟹'],
#   'latitude': 31.204048,
#   'longitude': 121.41156,
#   'name': '银河咖啡厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 229.0,
#   'avg_rating': 30.0,
#   'business_id': 503625,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '北极贝', '羊排'],
#   'latitude': 31.2031,
#   'longitude': 121.42992,
#   'name': '银星皇冠假日酒店星缘咖啡厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 53.0,
#   'avg_rating': 30.0,
#   'business_id': 503639,
#   'category': '烧烤',
#   'city': '上海',
#   'cn_tag': ['烤馒头', '金针菇', '鸡中翅'],
#   'latitude': 31.14378,
#   'longitude': 121.42915,
#   'name': '九头鸟烧烤(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 49.0,
#   'avg_rating': 30.0,
#   'business_id': 503645,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['酸菜鱼锅底', '骨头煲', '骨头锅底'],
#   'latitude': 31.38427,
#   'longitude': 121.2425,
#   'name': '川福火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 46.0,
#   'avg_rating': 30.0,
#   'business_id': 503646,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['冻豆腐', '骨头汤底'],
#   'latitude': 31.145147,
#   'longitude': 121.11594,
#   'name': '川源火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 60.0,
#   'avg_rating': 30.0,
#   'business_id': 503647,
#   'category': '烧烤',
#   'city': '上海',
#   'cn_tag': ['台湾香肠', '烤鸡翅', '羊肉串'],
#   'latitude': 31.235214,
#   'longitude': 121.52179,
#   'name': '图门烧烤(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 79.0,
#   'avg_rating': 35.0,
#   'business_id': 503689,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['临江嫩牛肉', '宽粉', '鸭血'],
#   'latitude': 31.158085,
#   'longitude': 121.34709,
#   'name': '临江门老火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 26.0,
#   'avg_rating': 30.0,
#   'business_id': 503707,
#   'category': '东北菜',
#   'city': '上海',
#   'cn_tag': ['韭菜蛋饺', '饺子', '黄瓜蘸酱'],
#   'latitude': 31.200693,
#   'longitude': 121.44607,
#   'name': '哈尔滨刘记饺子馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 64.0,
#   'avg_rating': 30.0,
#   'business_id': 503713,
#   'category': '新疆菜',
#   'city': '上海',
#   'cn_tag': ['烧烤', '牛肉锅贴', '羊肉串'],
#   'latitude': 31.174416,
#   'longitude': 121.49275,
#   'name': '浦东清真饭店(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 48.0,
#   'avg_rating': 30.0,
#   'business_id': 503757,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['干锅牛蛙', '平锅手撕包菜', '跺椒鱼头'],
#   'latitude': 31.181072,
#   'longitude': 121.392746,
#   'name': '毛家湘味楼(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 101.0,
#   'avg_rating': 35.0,
#   'business_id': 503764,
#   'category': '台湾菜',
#   'city': '上海',
#   'cn_tag': ['三杯鸡', '花生冰沙', '菠萝油条虾'],
#   'latitude': 31.21079,
#   'longitude': 121.44808,
#   'name': '小城故事(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 46.0,
#   'avg_rating': 30.0,
#   'business_id': 503811,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['一桶鸡', '剁椒鱼头', '爱情买卖'],
#   'latitude': 31.246855,
#   'longitude': 121.44488,
#   'name': '湖南乡村风味(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 68.0,
#   'avg_rating': 40.0,
#   'business_id': 503828,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['羊肉', '肥牛', '肥羊肉'],
#   'latitude': 31.15242,
#   'longitude': 121.11764,
#   'name': '小肥羊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 87.0,
#   'avg_rating': 35.0,
#   'business_id': 503829,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['羊肉', '肥羊肉', '金针菇'],
#   'latitude': 31.247538,
#   'longitude': 121.57641,
#   'name': '小肥羊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 47.0,
#   'avg_rating': 35.0,
#   'business_id': 503936,
#   'category': '烧烤',
#   'city': '上海',
#   'cn_tag': ['羊肉串', '脆骨', '鸡翅'],
#   'latitude': 31.169125,
#   'longitude': 121.44417,
#   'name': '小李烧烤(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 135.0,
#   'avg_rating': 40.0,
#   'business_id': 503951,
#   'category': '韩国料理',
#   'city': '上海',
#   'cn_tag': ['泡菜', '烤五花肉', '烤牛肉'],
#   'latitude': 31.21018,
#   'longitude': 121.40744,
#   'name': '平壤青柳馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 228.0,
#   'avg_rating': 40.0,
#   'business_id': 503957,
#   'category': '韩国料理',
#   'city': '上海',
#   'cn_tag': ['泡菜', '烤牛肉', '神仙炉'],
#   'latitude': 31.189669,
#   'longitude': 121.4379,
#   'name': '平壤玉流酒家(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 49.0,
#   'avg_rating': 40.0,
#   'business_id': 503992,
#   'category': '贵州菜',
#   'city': '上海',
#   'cn_tag': ['剁椒鱼头', '干锅牛蛙', '水煮鱼'],
#   'latitude': 31.170135,
#   'longitude': 121.4891,
#   'name': '川黔菜(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 211.0,
#   'avg_rating': 40.0,
#   'business_id': 503998,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['烤牛肉', '烤牛舌', '烤羊肉'],
#   'latitude': 31.23932,
#   'longitude': 121.582954,
#   'name': '拉蒂娜Latina(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 45.0,
#   'avg_rating': 30.0,
#   'business_id': 504059,
#   'category': '烧烤',
#   'city': '上海',
#   'cn_tag': ['脆骨', '香菇', '鸡翅'],
#   'latitude': 31.21215,
#   'longitude': 121.49007,
#   'name': '老刘烧烤(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 111.0,
#   'avg_rating': 35.0,
#   'business_id': 504079,
#   'category': '台湾菜',
#   'city': '上海',
#   'cn_tag': ['三杯鸡', '柠檬虾', '胡椒虾'],
#   'latitude': 31.206644,
#   'longitude': 121.3869,
#   'name': '宜兰大鼎活虾(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 71.0,
#   'avg_rating': 35.0,
#   'business_id': 504081,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['剁椒鱼头', '口味猪手', '铁板包菜'],
#   'latitude': 31.213566,
#   'longitude': 121.44543,
#   'name': '湖南乡村风味(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 47.0,
#   'avg_rating': 20.0,
#   'business_id': 504082,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['肥羊肉', '酸梅汤', '骨头锅底'],
#   'latitude': 31.232336,
#   'longitude': 121.47688,
#   'name': '京都涮涮锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 40.0,
#   'avg_rating': 30.0,
#   'business_id': 504128,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['孜然羊排'],
#   'latitude': 31.17712,
#   'longitude': 121.37533,
#   'name': '湘宝园土鸡馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 57.0,
#   'avg_rating': 20.0,
#   'business_id': 504132,
#   'category': '台湾菜',
#   'city': '上海',
#   'cn_tag': ['瑞士牛排', '荠菜百叶包'],
#   'latitude': 31.25159,
#   'longitude': 121.5784,
#   'name': '佳笛台湾海鲜楼(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 120.0,
#   'avg_rating': 35.0,
#   'business_id': 504138,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '上等牛小排', '牛舌'],
#   'latitude': 31.186657,
#   'longitude': 121.433975,
#   'name': '神户烧肉日本料理(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 56.0,
#   'avg_rating': 30.0,
#   'business_id': 504161,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['乌梅汁', '羊肉', '骨头锅底'],
#   'latitude': 31.336046,
#   'longitude': 121.44538,
#   'name': '东东骨头王火锅城(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 88.0,
# ...
#   'cn_tag': ['烤五花肉', '烤拌牛肉', '蛋卷'],
#   'latitude': 31.22655,
#   'longitude': 121.55926,
#   'name': '炉边情谈(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 42.0,
#   'avg_rating': 30.0,
#   'business_id': 2244856,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['剁椒鱼头', '夫妻肺片', '干锅牛蛙'],
#   'latitude': 31.25119,
#   'longitude': 121.427376,
#   'name': '旺角饭店(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 50.0,
#   'avg_rating': 35.0,
#   'business_id': 2248516,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['剁椒鱼头', '小炒鸡杂', '手撕包菜'],
#   'latitude': 31.384167,
#   'longitude': 121.24282,
#   'name': '湘会天下(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 30.0,
#   'avg_rating': 30.0,
#   'business_id': 2249260,
#   'category': '东北菜',
#   'city': '上海',
#   'cn_tag': ['东北大拉皮', '锅包肉', '韭菜盒子'],
#   'latitude': 31.24465,
#   'longitude': 121.582344,
#   'name': '东北菜馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 128.0,
#   'avg_rating': 35.0,
#   'business_id': 2253019,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '多春鱼', '自助餐'],
#   'latitude': 30.729378,
#   'longitude': 121.351845,
#   'name': '海鸥大厦(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 52.0,
#   'avg_rating': 30.0,
#   'business_id': 2256463,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['剁椒鱼头', '土钵饭', '手撕包菜'],
#   'latitude': 31.315866,
#   'longitude': 121.3865,
#   'name': '苗家炭火烤鱼(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 50.0,
#   'avg_rating': 30.0,
#   'business_id': 2257918,
#   'category': '烧烤',
#   'city': '上海',
#   'cn_tag': ['小龙虾', '烧烤', '烧鸡公'],
#   'latitude': 31.171976,
#   'longitude': 121.35163,
#   'name': '航华369家常菜(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 149.0,
#   'avg_rating': 35.0,
#   'business_id': 2260687,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['牛肉丸', '蛇肉', '蛇肉火锅'],
#   'latitude': 31.2064,
#   'longitude': 121.38663,
#   'name': '汕头蛇肉打边炉(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 48.0,
#   'avg_rating': 30.0,
#   'business_id': 2261797,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['剁椒鱼头', '手撕包菜', '酸豆角肉末'],
#   'latitude': 31.236504,
#   'longitude': 121.448875,
#   'name': '辉腾湘菜馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 65.0,
#   'avg_rating': 30.0,
#   'business_id': 2262169,
#   'category': '韩国料理',
#   'city': '上海',
#   'cn_tag': ['五花肉', '炒年糕', '石锅拌饭'],
#   'latitude': 31.041664,
#   'longitude': 121.75714,
#   'name': '釜轩料理(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 22.0,
#   'avg_rating': 30.0,
#   'business_id': 2264008,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['干锅牛蛙', '椒盐排条', '花菜'],
#   'latitude': 31.21839,
#   'longitude': 121.36191,
#   'name': '虹天火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 38.0,
#   'avg_rating': 30.0,
#   'business_id': 2264470,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['冻豆腐', '羊肉', '金针菇'],
#   'latitude': 31.03875,
#   'longitude': 121.21849,
#   'name': '傣妹(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 23.0,
#   'avg_rating': 35.0,
#   'business_id': 2264503,
#   'category': '素菜',
#   'city': '上海',
#   'cn_tag': ['方便面', '素鸡腿', '腊肠'],
#   'latitude': 31.255125,
#   'longitude': 121.50742,
#   'name': '齐善素食(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 199.0,
#   'avg_rating': 40.0,
#   'business_id': 2265715,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '煎鹅肝', '甜点'],
#   'latitude': 31.211254,
#   'longitude': 121.534584,
#   'name': '东锦江希尔顿逸林旋转餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 52.0,
#   'avg_rating': 40.0,
#   'business_id': 2269621,
#   'category': '烧烤',
#   'city': '上海',
#   'cn_tag': ['带子', '扇贝', '生蚝'],
#   'latitude': 31.242008,
#   'longitude': 121.54144,
#   'name': '广东祥记蚝庄(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 41.0,
#   'avg_rating': 30.0,
#   'business_id': 2269720,
#   'category': '烧烤',
#   'city': '上海',
#   'cn_tag': ['金针菇'],
#   'latitude': 31.315865,
#   'longitude': 121.38613,
#   'name': '马源斋烧烤(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 37.0,
#   'avg_rating': 30.0,
#   'business_id': 2270242,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['肥牛', '肥羊', '金针菇'],
#   'latitude': 31.193268,
#   'longitude': 121.69831,
#   'name': '傣妹(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 69.0,
#   'avg_rating': 35.0,
#   'business_id': 2271520,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['水煮鲶鱼', '酸梅汤', '馋嘴牛蛙'],
#   'latitude': 31.21214,
#   'longitude': 121.47467,
#   'name': '厚味香辣馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 23.0,
#   'avg_rating': 30.0,
#   'business_id': 2272399,
#   'category': '韩国料理',
#   'city': '上海',
#   'cn_tag': ['大酱汤', '石锅拌饭', '辣牛肉汤'],
#   'latitude': 31.024818,
#   'longitude': 121.43498,
#   'name': 'MANNA(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 65.0,
#   'avg_rating': 35.0,
#   'business_id': 2274217,
#   'category': '台湾菜',
#   'city': '上海',
#   'cn_tag': ['沙茶牛肉煲', '红豆冰沙', '肉燥饭'],
#   'latitude': 31.19451,
#   'longitude': 121.43752,
#   'name': '一茶一坐(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 92.0,
#   'avg_rating': 35.0,
#   'business_id': 2274784,
#   'category': '韩国料理',
#   'city': '上海',
#   'cn_tag': ['五花肉', '南瓜粥', '牛舌'],
#   'latitude': 31.192099,
#   'longitude': 121.442505,
#   'name': 'PANKOO釜山料理(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 80.0,
#   'avg_rating': 40.0,
#   'business_id': 2280445,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['羊肉', '虾滑', '鲜虾丸'],
#   'latitude': 31.248335,
#   'longitude': 121.4443,
#   'name': '小金捞上汤火锅料理(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 57.0,
#   'avg_rating': 35.0,
#   'business_id': 2283676,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['烤鱼', '羊蝎子火锅', '腊肉茶树菇'],
#   'latitude': 31.233635,
#   'longitude': 121.52039,
#   'name': '小四川鱼庄(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 38.0,
#   'avg_rating': 30.0,
#   'business_id': 2284894,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['鸡公煲'],
#   'latitude': 31.174677,
#   'longitude': 121.49249,
#   'name': '重庆鸡公煲(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 47.0,
#   'avg_rating': 30.0,
#   'business_id': 2285212,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['栗子色拉', '馋嘴蛙'],
#   'latitude': 31.264309,
#   'longitude': 121.58978,
#   'name': '佳佳美食林(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 156.0,
#   'avg_rating': 35.0,
#   'business_id': 2285215,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '抹茶味哈根达斯冰淇淋', '甜品'],
#   'latitude': 31.22761,
#   'longitude': 121.48802,
#   'name': '豫园万丽咖啡厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 19.0,
#   'avg_rating': 30.0,
#   'business_id': 2286742,
#   'category': '烧烤',
#   'city': '上海',
#   'cn_tag': ['羊肉', '金针菇', '鸡脆骨'],
#   'latitude': 31.26327,
#   'longitude': 121.476425,
#   'name': '路边烧烤摊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 30.0,
#   'avg_rating': 30.0,
#   'business_id': 2286943,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['干锅千叶豆腐', '玉米烙', '辣子鸡'],
#   'latitude': 31.016676,
#   'longitude': 121.43118,
#   'name': '寻常人家(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 30.0,
#   'avg_rating': 35.0,
#   'business_id': 2287126,
#   'category': '烧烤',
#   'city': '上海',
#   'cn_tag': ['掌中宝', '羊肉串', '金针菇'],
#   'latitude': 31.2087,
#   'longitude': 121.36229,
#   'name': '清真胖子烧烤河南羊肉烩面(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 81.0,
#   'avg_rating': 40.0,
#   'business_id': 2287456,
#   'category': '素菜',
#   'city': '上海',
#   'cn_tag': ['QQ面', '外婆红烧肉', '铁板菲力牛排'],
#   'latitude': 31.21671,
#   'longitude': 121.46011,
#   'name': '新素代(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 14.0,
#   'avg_rating': 40.0,
#   'business_id': 2288350,
#   'category': '烧烤',
#   'city': '上海',
#   'cn_tag': ['烤臭豆腐', '蒜苗', '鸡翅'],
#   'latitude': 31.324835,
#   'longitude': 121.53463,
#   'name': '开鲁路清真烧烤小摊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 29.0,
#   'avg_rating': 40.0,
#   'business_id': 2289148,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['回锅肉', '干煸土豆丝', '水煮鱼片'],
#   'latitude': 31.293419,
#   'longitude': 121.50786,
#   'name': '邻里川菜馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 69.0,
#   'avg_rating': 30.0,
#   'business_id': 2289769,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['羊肉', '羊脊骨', '羊蝎子'],
#   'latitude': 31.087965,
#   'longitude': 121.37532,
#   'name': '小尾羊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 40.0,
#   'avg_rating': 40.0,
#   'business_id': 2289823,
#   'category': '东北菜',
#   'city': '上海',
#   'cn_tag': ['地三鲜', '小鸡炖蘑菇', '韭菜鸡蛋饺子'],
#   'latitude': 31.278803,
#   'longitude': 121.49602,
#   'name': '东北人家饺子王(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 62.0,
#   'avg_rating': 30.0,
#   'business_id': 2290597,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['热气羊肉', '特制调料', '特色酱料'],
#   'latitude': 31.168858,
#   'longitude': 121.48426,
#   'name': '馨宝火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 40.0,
#   'avg_rating': 40.0,
#   'business_id': 2292034,
#   'category': '烧烤',
#   'city': '上海',
#   'cn_tag': ['掌中宝', '牛肉', '鸡排'],
#   'latitude': 31.24085,
#   'longitude': 121.40932,
#   'name': '冬明本帮烧烤(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 80.0,
#   'avg_rating': 35.0,
#   'business_id': 2294248,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['手撕包菜', '秘制串烧虾', '鸳鸯鱼头'],
#   'latitude': 31.219065,
#   'longitude': 121.416534,
#   'name': '望湘园(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 122.0,
#   'avg_rating': 35.0,
#   'business_id': 2294842,
#   'category': '西餐',
#   'city': '上海',
#   'cn_tag': ['德国啤酒', '德国猪肘', '面包圈'],
#   'latitude': 31.215929,
#   'longitude': 121.54222,
#   'name': '慕尼黑皇家啤酒屋(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 260.0,
#   'avg_rating': 35.0,
#   'business_id': 2295022,
#   'category': '粤菜',
#   'city': '上海',
#   'cn_tag': ['元宝虾', '黑椒牛仔骨', '龙虾'],
#   'latitude': 31.231127,
#   'longitude': 121.50224,
#   'name': '海龙海鲜舫(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 52.0,
#   'avg_rating': 45.0,
#   'business_id': 2296198,
#   'category': '新疆菜',
#   'city': '上海',
#   'cn_tag': ['大盘鸡', '手抓饭', '羊肉串'],
#   'latitude': 31.218115,
#   'longitude': 121.48205,
#   'name': '乐乐新疆风味餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 57.0,
#   'avg_rating': 30.0,
#   'business_id': 2298628,
#   'category': '台湾菜',
#   'city': '上海',
#   'cn_tag': ['三杯鸡', '肉燥', '芒果雪酪'],
#   'latitude': 31.231087,
#   'longitude': 121.55452,
#   'name': '一茶一坐(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 35.0,
#   'avg_rating': 30.0,
#   'business_id': 2306407,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['鸡公煲'],
#   'latitude': 31.223633,
#   'longitude': 121.51985,
#   'name': '重庆鸡公煲(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 58.0,
#   'avg_rating': 35.0,
#   'business_id': 2311861,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['干锅牛蛙', '活鱼火锅', '鱼丸'],
#   'latitude': 31.27389,
#   'longitude': 121.58093,
#   'name': '泰煌火锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 22.0,
#   'avg_rating': 30.0,
#   'business_id': 2312401,
#   'category': '新疆菜',
#   'city': '上海',
#   'cn_tag': ['凉皮', '牛肉拉面', '羊肉串'],
#   'latitude': 31.196222,
#   'longitude': 121.69186,
#   'name': '小西北饮食林(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 41.0,
#   'avg_rating': 35.0,
#   'business_id': 2313505,
#   'category': '台湾菜',
#   'city': '上海',
#   'cn_tag': ['地瓜叶', '米苔目', '综合冰'],
#   'latitude': 31.172812,
#   'longitude': 121.36478,
#   'name': '米苔目面食馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 22.0,
#   'avg_rating': 30.0,
#   'business_id': 2316307,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['咸蛋黄玉米', '玉米烙', '酸菜鱼'],
#   'latitude': 31.049643,
#   'longitude': 121.21662,
#   'name': '蜀蜀家(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 5.0,
#   'avg_rating': 30.0,
#   'business_id': 2316886,
#   'category': '烧烤',
#   'city': '上海',
#   'cn_tag': ['烤鱿鱼', '贡丸', '骨肉相连'],
#   'latitude': 31.280848,
#   'longitude': 121.482475,
#   'name': '赤峰路轻轨站前小吃摊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 77.0,
#   'avg_rating': 35.0,
#   'business_id': 2317444,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['羊肉', '金针菇', '骨头锅'],
#   'latitude': 31.282398,
#   'longitude': 121.61048,
#   'name': '蜀膳传火锅传奇(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 80.0,
#   'avg_rating': 35.0,
#   'business_id': 2317708,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['酸菜鱼锅底', '金针菇', '骨头锅底'],
#   'latitude': 31.313305,
#   'longitude': 121.4586,
#   'name': '陌生人火锅餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 24.0,
#   'avg_rating': 30.0,
#   'business_id': 2318017,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['朋友聚餐'],
#   'latitude': 31.139366,
#   'longitude': 121.41726,
#   'name': '老客来(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 88.0,
#   'avg_rating': 40.0,
#   'business_id': 2318884,
#   'category': '素菜',
#   'city': '上海',
#   'cn_tag': ['火锅', '翡翠饺子', '豆腐布丁'],
#   'latitude': 31.203304,
#   'longitude': 121.4257,
#   'name': '干叶子茶料理(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 13.0,
#   'avg_rating': 30.0,
#   'business_id': 2319532,
#   'category': '烧烤',
#   'city': '上海',
#   'cn_tag': ['羊肉串', '金针菇'],
#   'latitude': 31.26585,
#   'longitude': 121.481995,
#   'name': '多伦路烧烤路边摊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 65.0,
#   'avg_rating': 30.0,
#   'business_id': 2320852,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['印度飞饼', '烤羊排', '羊肉'],
#   'latitude': 31.048944,
#   'longitude': 121.77695,
#   'name': '苏武牧羊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 92.0,
#   'avg_rating': 35.0,
#   'business_id': 2320957,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['墨鱼滑', '羊肉', '虾滑'],
#   'latitude': 31.03875,
#   'longitude': 121.21849,
#   'name': '嘟捞咪坊(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 236.0,
#   'avg_rating': 35.0,
#   'business_id': 2321551,
#   'category': '自助餐',
#   'city': '上海',
#   'cn_tag': ['三文鱼', '牛排', '甜品'],
#   'latitude': 31.229527,
#   'longitude': 121.52138,
#   'name': '锦江汤臣洲际大酒店中庭(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 38.0,
#   'avg_rating': 30.0,
#   'business_id': 2322400,
#   'category': '东北菜',
#   'city': '上海',
#   'cn_tag': ['可送外卖'],
#   'latitude': 31.144506,
#   'longitude': 121.32758,
#   'name': '老洪饺子馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 17.0,
#   'avg_rating': 30.0,
#   'business_id': 2324596,
#   'category': '烧烤',
#   'city': '上海',
#   'cn_tag': ['牛板筋', '羊肉串', '羊腰'],
#   'latitude': 31.273373,
#   'longitude': 121.448906,
#   'name': '大宁碳火烧烤(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 30.0,
#   'avg_rating': 30.0,
#   'business_id': 2324863,
#   'category': '川菜',
#   'city': '上海',
#   'cn_tag': ['回锅肉', '沸腾鱼', '玉米烙'],
#   'latitude': 31.049644,
#   'longitude': 121.20212,
#   'name': '蜀味馆(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 163.0,
#   'avg_rating': 45.0,
#   'business_id': 2327323,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['扇贝', '海鲜拼盘', '雪花牛肉'],
#   'latitude': 31.185621,
#   'longitude': 121.36869,
#   'name': '竹北海道昆布锅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 55.0,
#   'avg_rating': 30.0,
#   'business_id': 2328286,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['土鸡', '本鸡', '鸡血'],
#   'latitude': 31.154518,
#   'longitude': 121.38198,
#   'name': '新招鲜本地鸡窝(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 47.0,
#   'avg_rating': 30.0,
#   'business_id': 2329702,
#   'category': '火锅',
#   'city': '上海',
#   'cn_tag': ['南瓜饼', '特色骨头锅', '骨头锅'],
#   'latitude': 31.196398,
#   'longitude': 121.68969,
#   'name': '东东骨头王火锅城(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 19.0,
#   'avg_rating': 35.0,
#   'business_id': 2329903,
#   'category': '韩国料理',
#   'city': '上海',
#   'cn_tag': ['炒年糕', '烤肉', '石锅拌饭'],
#   'latitude': 30.831472,
#   'longitude': 121.513885,
#   'name': '三只熊韩国料理餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 87.0,
#   'avg_rating': 30.0,
#   'business_id': 2332903,
#   'category': '烧烤',
#   'city': '上海',
#   'cn_tag': ['带子', '扇贝', '生蚝'],
#   'latitude': 31.321913,
#   'longitude': 121.44634,
#   'name': '刘记大蚝门海鲜烧烤(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 72.0,
#   'avg_rating': 35.0,
#   'business_id': 2335114,
#   'category': '新疆菜',
#   'city': '上海',
#   'cn_tag': ['大盘鸡', '羊肉串', '酸奶'],
#   'latitude': 31.22284,
#   'longitude': 121.44244,
#   'name': '新疆伊宁远征餐厅(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  {'avg_price': 47.0,
#   'avg_rating': 30.0,
#   'business_id': 2335201,
#   'category': '湘菜',
#   'city': '上海',
#   'cn_tag': ['双色鱼头', '干锅牛杂', '珍珠扣肉'],
#   'latitude': 31.263563,
#   'longitude': 121.47655,
#   'name': '吃湘喝辣(这是一条测试商户数据，仅用于测试开发，开发完成后请申请正式数据...)'},
#  ...]
