# %%
# %matplotlib notebook

import os
import sys
from operator import itemgetter
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
#from ipyleaflet import (Map, GeoJSON)

sns.set()

from sklearn.cluster import DBSCAN

import matplotlib.dates as mdates
from matplotlib.colors import rgb2hex
import json

def get_geojson(features):
    return {
        'type': 'FeatureCollection',
        'features': features
    }

def save_geojson(features, directory, file_name):
    if not os.path.exists(directory): os.makedirs(directory)
    f = os.path.join(directory, file_name + '.geojson')
    geojson = {
      'type': 'FeatureCollection',
      'features': features
    }
    with open(f, 'w') as outfile:
        json.dump(geojson, outfile, indent = 4)
    print('Saved to ' + f)

def to_geojson(df, groupby, lat, lng, cols, dumps=True):

    def get_features(row, color):
        properties = { k: str(v) for k,v in zip(cols,[row[col] for col in cols]) }
        properties['marker-color'] = rgb2hex(color[:3])
        return {
            'type': 'Feature',
                'geometry': {
                'type': 'Point',
                'coordinates': [row[lng], row[lat]]
            },
            'properties': properties
        }

    clusters = df.groupby(groupby)

    features = []
    colors = plt.cm.Spectral(np.linspace(0, 1, len(clusters)))
    for name, group in clusters:
        i = np.random.randint(colors.shape[0])
        color = colors[i]
        group.apply(lambda row: features.append(get_features(row, color)), axis=1)
        colors = np.delete(colors, i, 0)

    if dumps:
        return json.dumps(get_geojson(features))
    return get_geojson(features)

# %%
nb_dir = os.path.normpath(os.path.join(os.getcwd(), '..'))
os.listdir(nb_dir)
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

f = '../data/UTSEUS-shanghai-flickr.sqlite'

# %%
import sqlite3
conn = sqlite3.connect(f)
cursor = conn.cursor()
cursor.execute("""
SELECT * FROM photos
""")
photos = pd.DataFrame(cursor.fetchall())

# %%
photos.head()
# Out:
#          0          1           2             3   4           5     6   7   \
# 0  12786061  31.239682  121.497266  23804952@N00  15  22726052.0  2004   9
# 1  21048909  31.234380  121.494541  40264825@N00  16  22726050.0  2005   3
# 2  21048962  31.234380  121.494541  40264825@N00  16  22726050.0  2005   6
# 3  21048995  31.234380  121.494541  40264825@N00  16  22726050.0  2005   6
# 4  21049047  31.234380  121.494541  40264825@N00  16  22726050.0  2004  11
#
#    8                               9   \
# 0  25               Needle in the Sky
# 1  22                        Skywards
# 2  23                           Bund2
# 3  23                   RoomWithaView
# 4  30  Bund, Early Morning (Shanghai)
#
#                                                 10  \
# 0  sky 2004 architecture shanghai pearltower dscp8
# 1                         holga cityscape shanghai
# 2                         holga cityscape shanghai
# 3              holga cityscape shanghai hotelrooms
# 4                         holga cityscape shanghai
#
#                                               11  \
# 0                       Pearl TV Tower, Shanghai
# 1                          Holga Shanghai Places
# 2                          Holga Shanghai Places
# 3  Holga Shanghai Places\n\nCamera: Holga 120N\n
# 4                             Camera: Holga 120N
#
#                                                   12
# 0  http://farm1.staticflickr.com/9/12786061_a6b55...
# 1  http://farm1.staticflickr.com/16/21048909_3a5c...
# 2  http://farm1.staticflickr.com/16/21048962_98b0...
# 3  http://farm1.staticflickr.com/15/21048995_8cd6...
# 4  http://farm1.staticflickr.com/15/21049047_51f8...

# %%
# Don't forget to remove "sample" to get full dataset
data_dbscan = photos[[1, 2, 10]].sample(500)
data_dbscan.columns = ['latitude', 'longitude', 'tags']
data_dbscan.head()
X = data_dbscan[['latitude', 'longitude']].values

# %%
kms_per_radian = 6371.0088

def compute_dbscan(meters):
    epsilon = (meters * 0.001) / kms_per_radian
    db = DBSCAN(eps=epsilon, algorithm='ball_tree', metric='haversine').fit(np.radians(X))
    return db.labels_

computings = map(compute_dbscan, range(100, 300))
n_computings = map(lambda x: (len(set(x)), x), computings)
labels = max(n_computings, key=itemgetter(0))[1]

for label in set(labels):
    df = data_dbscan[(labels == label)]
    data_dbscan.loc[df.index, 'cluster_num'] = int(label)

# %%
data_dbscan.sample(10)
# Out:
#         latitude   longitude  \
# 42647  31.200000  121.500000
# 25759  31.224041  121.448621
# 21046  31.240282  121.437388
# 17672  31.218700  121.412529
# 35901  31.237388  121.486680
# 34799  31.206388  121.467222
# 14993  31.242920  121.440306
# 37995  31.247709  121.472618
# 34674  31.214966  121.419088
# 31149  31.238659  121.498661
#
#                                                     tags  cluster_num
# 42647  square lofi squareformat iphoneography instagr...         12.0
# 25759                                               None         -1.0
# 21046  square squareformat iphoneography instagramapp...         -1.0
# 17672  square nashville squareformat iphoneography in...         -1.0
# 35901                                               None          1.0
# 34799     kids astrid 上海 ilona eplin 日月光中心 富邦华一银行 富邦華一銀行         -1.0
# 14993       china temple dragon buddha jade chine boudha         -1.0
# 37995                                           shanghai         -1.0
# 34674  china food yum shanghai chinese eat noodle res...         -1.0
# 31149  tower skyline night lights bottle shanghai jin...         -1.0

# %%
def compute_middle_point(df):
    tags = df['tags'].str.cat(sep=' ')
    return df.assign(tags=tags)[:1]

final_data = data_dbscan.groupby('cluster_num').apply(lambda df: compute_middle_point(df))
final_data
# Out:
#                     latitude   longitude  \
# cluster_num
# -1.0        6499   31.237793  121.481194
#  0.0        8435   31.209607  121.463788
#  1.0        5708   31.239383  121.485511
#  2.0        34231  31.219683  121.471625
#  3.0        43209  31.230655  121.473780
#  4.0        14124  31.238881  121.498019
#  5.0        3711   31.224986  121.440977
#  6.0        5632   31.239022  121.489713
#  7.0        7531   31.236305  121.471641
#  8.0        8814   31.222513  121.470152
#  9.0        14790  31.237829  121.499176
#  10.0       14259  31.240911  121.498961
#  11.0       2602   31.235958  121.491022
#  12.0       31253  31.200000  121.500000
#  13.0       3867   31.264709  121.481024
#  14.0       468    31.229167  121.487500
#  15.0       43137  31.237777  121.476388
#  16.0       36621  31.244984  121.485614
#
#                                                                 tags  \
# cluster_num
# -1.0        6499   street travel portrait color 50mm shanghai str...
#  0.0        8435   square squareformat inkwell iphoneography inst...
#  1.0        5708   china shanghai thebund shanghaishi shanghái sq...
#  2.0        34231  square squareformat iphoneography instagramapp...
#  3.0        43209  1dx asia canontse17mmf4l china chinese eos1dx ...
#  4.0        14124  square squareformat inkwell iphoneography inst...
#  5.0        3711   china shanghai square squareformat juno iphone...
#  6.0        5632   china shanghai 中国 上海 puxi 浦西 shanghai 中国 上海 外灘...
#  7.0        7531   world mms china shanghai sony bund silkfactory...
#  8.0        8814   china holiday shanghai egg eat brunch xintiand...
#  9.0        14790  street city building architecture skyscraper n...
#  10.0       14259  china city winter tower skyline night lights c...
#  11.0       2602   china tour shanghai beijing hong kong yangshao...
#  12.0       31253  square squareformat iphoneography instagramapp...
#  13.0       3867   square squareformat iphoneography instagramapp...
#  14.0       468    china shanghai yuyuantemple nouhailler china v...
#  15.0       43137         china city cn shanghai library shanghaishi
#  16.0       36621  bridge blackandwhite bw monochrome canon mono ...
#
#                    cluster_num
# cluster_num
# -1.0        6499          -1.0
#  0.0        8435           0.0
#  1.0        5708           1.0
#  2.0        34231          2.0
#  3.0        43209          3.0
#  4.0        14124          4.0
#  5.0        3711           5.0
#  6.0        5632           6.0
#  7.0        7531           7.0
#  8.0        8814           8.0
#  9.0        14790          9.0
#  10.0       14259         10.0
#  11.0       2602          11.0
#  12.0       31253         12.0
#  13.0       3867          13.0
#  14.0       468           14.0
#  15.0       43137         15.0
#  16.0       36621         16.0

# %%
blacklist = [
    "chine",
    "shanghai",
    "travel",
    "square",
    "city",
    "china",
    "cn",
    "squareformat",
    "asia",
    "uploaded:by=instagram",
    "shanghaishi",
    "iphoneography",
    "chinese",
    "instagramapp",
    "internations",
    "street",
    u'上海',
    u'中国',
  ]

# %%
for word in blacklist:
    final_data['tags'] = final_data['tags'].apply(lambda tags: tags.replace(word, ''))
final_data
# Out:
#                     latitude   longitude  \
# cluster_num
# -1.0        6499   31.237793  121.481194
#  0.0        8435   31.209607  121.463788
#  1.0        5708   31.239383  121.485511
#  2.0        34231  31.219683  121.471625
#  3.0        43209  31.230655  121.473780
#  4.0        14124  31.238881  121.498019
#  5.0        3711   31.224986  121.440977
#  6.0        5632   31.239022  121.489713
#  7.0        7531   31.236305  121.471641
#  8.0        8814   31.222513  121.470152
#  9.0        14790  31.237829  121.499176
#  10.0       14259  31.240911  121.498961
#  11.0       2602   31.235958  121.491022
#  12.0       31253  31.200000  121.500000
#  13.0       3867   31.264709  121.481024
#  14.0       468    31.229167  121.487500
#  15.0       43137  31.237777  121.476388
#  16.0       36621  31.244984  121.485614
#
#                                                                 tags  \
# cluster_num
# -1.0        6499     portrait color 50mm  photography portrait ol...
#  0.0        8435    format inkwell    four:venue=50482debe4b0ac40...
#  1.0        5708     thebund shi shanghái  format    old  houses ...
#  2.0        34231                                          format
#  3.0        43209  1dx  canontse17mmf4l  se eos1dx photography  w...
#  4.0        14124   format inkwell    four:venue=4bee4c152c082d7f...
#  5.0        3711                format juno     format     format
#  6.0        5632       puxi 浦西    外灘 浦東  river lights  nightshot ...
#  7.0        7531   world mms   sony bund silkfactory nex7    kitc...
#  8.0        8814    holiday  egg eat brunch xintiandi benedict ka...
#  9.0        14790    building architecture skyscraper nikon  angl...
#  10.0       14259    winter tower skyline night lights scape nigh...
#  11.0       2602    tour  beijing hong kong yangshao  pop   g mon...
#  12.0       31253   format     format hudson     gingham format  ...
#  13.0       3867    format      format    format clarendon     fo...
#  14.0       468      yuyuantemple nouhailler  viaje  losdiecisiet...
#  15.0       43137                                        library shi
#  16.0       36621  bridge blackandwhite bw monochrome canon mono ...
#
#                    cluster_num
# cluster_num
# -1.0        6499          -1.0
#  0.0        8435           0.0
#  1.0        5708           1.0
#  2.0        34231          2.0
#  3.0        43209          3.0
#  4.0        14124          4.0
#  5.0        3711           5.0
#  6.0        5632           6.0
#  7.0        7531           7.0
#  8.0        8814           8.0
#  9.0        14790          9.0
#  10.0       14259         10.0
#  11.0       2602          11.0
#  12.0       31253         12.0
#  13.0       3867          13.0
#  14.0       468           14.0
#  15.0       43137         15.0
#  16.0       36621         16.0

# %%
documents = final_data.to_dict('records')
for document in documents:
    document['tags'] = document['tags'].split(' ')
    document['tags'] = list(filter(None, document['tags']))
#documents[0]

# %%
import pymongo
client = pymongo.MongoClient('localhost', 27017)
db = client.explorify
flickr = db.flickr

# %%
flickr.insert_many(documents)

# %%
flickr.find().next()
# Out:
# {'_id': ObjectId('5a349c42c7553bc405031317'),
#  'cluster_num': -1.0,
#  'latitude': 31.242725,
#  'longitude': 121.482391,
#  'tags': ['architecture',
#   'golden',
#   'artist',
#   'hipster',
#   'historic',
#   'era',
#   '1933',
#   'laochangfang',
#   '2016',
#   'art',
#   'shi',
#   'bobby',
#   'zucco',
#   'bobbyzucco',
#   'pedrozucco',
#   'graffiti',
#   'arte',
#   'calle',
#   'rue',
#   'format',
#   'juno',
#   'geotagged',
#   'kmtoin',
#   '20150912',
#   '媽咪泰料',
#   'geo:lat=31216154',
#   'geo:lon=121470016',
#   'marathon',
#   '马拉松',
#   'dukong',
#   '杜空',
#   '2015国际马拉松',
#   'internationalmarathon2015',
#   'circus',
#   'format',
#   'food',
#   'life',
#   'yantai',
#   'urban',
#   'sonyrx1',
#   'format',
#   'lark',
#   'four:venue=5023c823e4b0862bdc3f9579',
#   'architecture',
#   'renzopiano',
#   'piecebypiece',
#   'winter',
#   'water',
#   'river',
#   'canal',
#   'ancient',
#   'historic',
#   'rivertown',
#   'zhujiajiao',
#   'wintersun',
#   'blue',
#   'highway',
#   'futuristic',
#   'iphone5sbackcamera415mmf22',
#   'library',
#   'libraries',
#   'conferences',
#   '2016',
#   'silf2016',
#   'winter',
#   'water',
#   'river',
#   'canal',
#   'ancient',
#   'historic',
#   'rivertown',
#   'zhujiajiao',
#   'wintersun',
#   'food',
#   'canon',
#   'foodporn',
#   'food',
#   '18200',
#   'steet',
#   'canoneos700d',
#   'thisis',
#   '2009',
#   'tour2009',
#   'acrobaticshow',
#   'johnmacsphotography',
#   'party',
#   'food',
#   'dinner',
#   'cuisine',
#   'restaurant',
#   'yum',
#   'se',
#   'delicious',
#   'eat',
#   'biz',
#   'ningbo',
#   'hongqiao',
#   'jiaofu',
#   'flowers',
#   'nature',
#   'garden',
#   'format',
#   'tower',
#   'apple',
#   'night',
#   'timelapse',
#   'pearl',
#   'oriental',
#   'bund',
#   'lujiazhui',
#   'iphone6',
#   'format',
#   'hudson',
#   'format',
#   'lark',
#   'format',
#   'night',
#   'nacht',
#   '中國',
#   'suzhoucreek',
#   '苏州河',
#   '虹口区',
#   'arndalarm',
#   'hongkoudistrict',
#   'fujianlu',
#   'mg381031k0e05c30wh30bl10or20klein',
#   'gingham',
#   'format',
#   '蘇州河',
#   '吳淞江',
#   'format',
#   'rise',
#   'hot',
#   'lunch',
#   'restaurant',
#   'yum',
#   'hong',
#   'delicious',
#   'spicy',
#   'sichuan',
#   'numb',
#   'skewer',
#   'format',
#   'amaro',
#   'format',
#   'kodak',
#   'leicam6',
#   'portra160',
#   'light',
#   'cinema',
#   '灯光',
#   '大厅',
#   '电影院',
#   '座椅',
#   '内部',
#   '影院',
#   '东昌电影院',
#   '2016',
#   'art',
#   'shi',
#   'bobby',
#   'zucco',
#   'bobbyzucco',
#   'pedrozucco',
#   'graffiti',
#   'arte',
#   'calle',
#   'rue',
#   '自然博物馆',
#   'sierra',
#   'format',
#   'valencia',
#   'format',
#   'format',
#   'metro',
#   'ciudadantigüa',
#   'format',
#   'ludwig',
#   'longexposure',
#   'light',
#   'motion',
#   'car',
#   'night',
#   'big',
#   'movement',
#   'scape',
#   'traffic',
#   'nacht',
#   'trail',
#   'stadt',
#   'lighttrails',
#   '旅游',
#   'center',
#   'auswahl',
#   'weltstadt',
#   'metropole',
#   'night',
#   'langzeitbelichtung',
#   'stadtleben',
#   '夜晚',
#   '市容',
#   '照明',
#   '颜色',
#   '灯火',
#   '多彩',
#   'grosstadt',
#   '旅游摄影',
#   '晚间',
#   '城市的',
#   '有声有色',
#   'marathon',
#   '马拉松',
#   'dukong',
#   '杜空',
#   '2015国际马拉松',
#   'internationalmarathon2015',
#   'format',
#   'mayfair',
#   'food',
#   'lunch',
#   'hongkong',
#   'restaurant',
#   'yum',
#   'se',
#   'tasty',
#   'eat',
#   'enjoy',
#   'nese',
#   'gingham',
#   'format',
#   '2015',
#   'format',
#   'kina',
#   'kina',
#   'live',
#   'journey',
#   'seven',
#   'mile',
#   'the',
#   'hat',
#   'fashion',
#   'miniature',
#   'doll',
#   'dress',
#   'handmade',
#   'clothes',
#   'bjd',
#   'blythe',
#   'outfits',
#   'msd',
#   'accessory',
#   'momoko',
#   'unoa',
#   'dollclothes',
#   'azone',
#   'obitsu',
#   'yosd',
#   'latiyellow',
#   'jerryberry',
#   'jiajiadoll',
#   'dorandoran',
#   's',
#   'traffic',
#   'se',
#   'bridge',
#   'sunset',
#   'water',
#   'boat',
#   'asie',
#   'kina',
#   'frenchconcession',
#   'zhonghua',
#   'schanghai',
#   'scene',
#   'g',
#   'kartelii',
#   'architecture',
#   'scapes',
#   'format',
#   'amaro',
#   '豐裕生煎',
#   'food',
#   'hot',
#   'lunch',
#   'restaurant',
#   'yum',
#   'se',
#   'eat',
#   'szechuan',
#   'spicy',
#   'sichuan',
#   'format',
#   'xproii',
#   'format',
#   'chromecast',
#   'april2016',
#   'flickrpublish',
#   'shi',
#   'camera:model=dscrx100m2',
#   'exif:isospeed=400',
#   'camera:make=sony',
#   'exif:focallength=1063mm',
#   'exif:make=sony',
#   'geo:=',
#   'geolocation',
#   'geo:lat=3121615',
#   'geo:state=shi',
#   'geo:lon=12146247222222',
#   'geo:country=',
#   'exif:aperture=ƒ40',
#   'exif:lens=28100mmf1849',
#   'exif:model=dscrx100m2',
#   'photinia',
#   'rosaceae',
#   '薔薇科',
#   'format',
#   'xproii',
#   'nuskin',
#   '2015',
#   '海洋量子號',
#   'fooddrink',
#   'arataisozaki',
#   '矶崎新',
#   'symphonyconcerthall',
#   '交响乐团音乐厅',
#   'format',
#   'ludwig',
#   'four:venue=5183da98498ec8f909329076',
#   'bike',
#   'bicycle',
#   '2016',
#   '骑行',
#   '100公里',
#   '环',
#   'new',
#   'garden',
#   'raod',
#   'yu',
#   'yuyuan',
#   '2014',
#   'yugarden',
#   'yuyuannewroad',
#   'templodelbudadejade',
#   'edomingo',
#   'mzuiko14150',
#   'olympusomdem10',
#   'lighting',
#   'architecture',
#   'design',
#   'italian',
#   'designer',
#   'interior',
#   'milano',
#   'architect',
#   'workshop',
#   'antiques',
#   'domusaurea',
#   'luxury',
#   'domus',
#   'shangai',
#   'politeico',
#   'aurea',
#   'lightingdesign',
#   'polidesign',
#   '2016',
#   '2014',
#   'quartiercolonialfrançais',
#   'skyline',
#   'nightshots',
#   'thebund',
#   'bw',
#   'buildings',
#   'reflections',
#   'boats',
#   'vehicles',
#   'rivers',
#   'trips',
#   'subjects',
#   'locations',
#   'crepuscularrays',
#   'occasions',
#   'urbanscenery',
#   'atmosphericphenomena',
#   'businessresearchtrips',
#   'photographicstylesandtechniques',
#   'pudong',
#   'shanghaï',
#   '2006',
#   'format',
#   'legs',
#   'g',
#   'pop',
#   '2006',
#   'iso400',
#   'leicam6',
#   'kodak400tx',
#   'boy',
#   'portrait',
#   'baby',
#   'horizontal',
#   'photography',
#   'se',
#   'indoors',
#   '50l',
#   '1dx',
#   'canonef50mmf12lusm',
#   'eos1dx',
#   'market',
#   'mercado',
#   'dog',
#   'pet',
#   'puppy',
#   '宠物',
#   '小狗',
#   'eq',
#   'thecat',
#   'cars',
#   'car',
#   'food',
#   'lunch',
#   'restaurant',
#   'yum',
#   'sweet',
#   'se',
#   'pork',
#   'eat',
#   'sour',
#   'limbo',
#   '2016',
#   'art',
#   'shi',
#   'bobby',
#   'zucco',
#   'bobbyzucco',
#   'pedrozucco',
#   'graffiti',
#   'arte',
#   'calle',
#   'rue',
#   'geotagged',
#   'kmtoin',
#   '大廈',
#   'geo:lat=31246387',
#   'geo:lon=121485321',
#   '20150428',
#   '2009',
#   'tour2009',
#   'johnmacsphotography',
#   'kina',
#   '2016',
#   'nevs',
#   'magnusjohansson',
#   'trravel',
#   'magnusjo',
#   'magnusjoyahoocom',
#   'format',
#   'uploaded:by=flickrmobile',
#   'flickriosapp:filter=nofilter',
#   'format',
#   'format',
#   'amaro',
#   'zhouzhuang',
#   'watervillage',
#   'pop',
#   'geotagged',
#   'kmtoin',
#   'geo:lat=31220732',
#   'geo:lon=121462936',
#   'vacation',
#   'sony',
#   'a7s',
#   'mpt2015',
#   'architecture',
#   'golden',
#   'artist',
#   'hipster',
#   'historic',
#   'era',
#   '1933',
#   'laochangfang',
#   'format',
#   'road',
#   'bridge',
#   'urban',
#   'station',
#   'skyline',
#   'creek',
#   'train',
#   'river',
#   'landscape',
#   'track',
#   'scape',
#   'suzhou',
#   'metro',
#   'district',
#   'trails',
#   'rail',
#   'railway',
#   'residential',
#   'putuo',
#   'zhabei',
#   'hengfeng',
#   'format',
#   'format',
#   'music',
#   'concert',
#   'gig',
#   'event',
#   'lastfm:event=4020881',
#   'format',
#   'juno',
#   '自然博物馆',
#   'marathon',
#   '马拉松',
#   'dukong',
#   '杜空',
#   '2015国际马拉松',
#   'internationalmarathon2015',
#   'panorama',
#   'skyline',
#   'scape',
#   'bluehour',
#   'pudong',
#   'jinmaotower',
#   'orientalpearltower',
#   'swfc',
#   'huangpuriver',
#   'mega',
#   'huangpujiang',
#   'tower',
#   'format',
#   'inkwell',
#   'format',
#   'library',
#   'shi',
#   'boy',
#   'de',
#   'nikon',
#   'blauw',
#   'afs',
#   'nijs',
#   'afd50mm18',
#   'd700',
#   'afs1835mmg',
#   'lofi',
#   'format',
#   'urban',
#   'art',
#   'art',
#   'architecture',
#   'canon',
#   'graffiti',
#   'photography',
#   'ist',
#   'moganshan',
#   'nese',
#   'thats',
#   'moganshanroad',
#   'life',
#   'thisis',
#   'canoneos700d',
#   'zai',
#   'beautiful',
#   'thisis',
#   'thatis',
#   'thatis',
#   '2015',
#   'love',
#   'ins',
#   'whatthe',
#   'timesout',
#   'format',
#   'bilal',
#   'mirza',
#   'ميرزا',
#   'بلال',
#   '米比勒',
#   'format',
#   'four:venue=4e4fcebd8877402b06c8496d',
#   'format',
#   'format',
#   'format',
#   'old',
#   'urban',
#   'blackandwhite',
#   'bw',
#   'architecture',
#   'canon',
#   'oldstyle',
#   'noiretblanc',
#   'photography',
#   'ist',
#   'old',
#   'oldarchitecture',
#   'nese',
#   'whiteandblack',
#   'searchitecture',
#   'thats',
#   'olddistrict',
#   'beautiful',
#   'life',
#   'thisis',
#   'canoneos700d',
#   'zai',
#   'beautiful',
#   'thisis',
#   'thatis',
#   'thatis',
#   '2015',
#   'ins',
#   'whatthe',
#   'timesout',
#   'kodak',
#   'leicam6',
#   'portra160',
#   'old',
#   'canon',
#   '18200',
#   'old',
#   'canoneos700d',
#   'beautiful',
#   'thatis',
#   'format',
#   'format',
#   'geotagged',
#   'kmtoin',
#   'geo:lat=31352823',
#   'geo:lon=121584465',
#   'uploaded:by=flickrmobile',
#   'flickriosapp:filter=nofilter',
#   'people',
#   'man',
#   'phil',
#   'watching',
#   'lonely',
#   'er',
#   'selectivecolour',
#   'centurypark',
#   '2015',
#   'flickrfriend',
#   'jiading',
#   'confuciustemple',
#   '石狮',
#   '孔庙',
#   '嘉定',
#   'seguardianlions',
#   'food',
#   'lunch',
#   'head',
#   'se',
#   'delicious',
#   'eat',
#   'eyeball',
#   'lamb',
#   'biz',
#   'urban',
#   'color',
#   'architecture',
#   'arquitectura',
#   'agua',
#   'ngc',
#   'samsung',
#   'viajes',
#   'nocturna',
#   'twop',
#   'artstyle',
#   'omot',
#   'note4',
#   'flickraward',
#   'samsungnote4',
#   'nikobo',
#   'joségarcíacobo',
#   'format',
#   'four:venue=515ac399e4b074b4993439d0',
#   'format',
#   'lofi',
#   'format',
#   'rise',
#   'old',
#   'architecture',
#   'canon',
#   'photography',
#   'town',
#   'photo',
#   'oldstyle',
#   'se',
#   'photography',
#   'ruelle',
#   'rue',
#   'oldtown',
#   '18200',
#   'old',
#   'oldarchitecture',
#   'sestyle',
#   'oldshop',
#   'photographiederue',
#   'thisis',
#   'canoneos700d',
#   'thisis',
#   'thatis',
#   'thatis',
#   '2009',
#   'tour2009',
#   'acrobaticshow',
#   'johnmacsphotography',
#   'format',
#   'amaro',
#   'four:venue=508ac648e4b0645d66253dda',
#   'canon',
#   'fire',
#   'fireworks',
#   'se',
#   'senewyear',
#   'newyear',
#   'february',
#   '18200',
#   'lunarnewyear',
#   'feu',
#   'nouvelan',
#   'feudartifice',
#   'fevrier',
#   'nouvelanchinois',
#   'canoneos700d',
#   'format',
#   'four:venue=4df8895f1495b7db1b0ec0a6',
#   'format',
#   'sunset',
#   'sm',
#   'format',
#   'format',
#   'museum',
#   'jiading',
#   '嘉定',
#   'bird',
#   'outdoors',
#   'flying',
#   'seagull',
#   '135l',
#   'huangpuriver',
#   'canonef135mmf2lusm',
#   '1dx',
#   'eos1dx',
#   'legs',
#   'daliah',
#   'ces',
#   'format',
#   'ludwig',
#   'ruelle',
#   'nichengqiao',
#   'portrait',
#   'musician',
#   'guy',
#   'fashion',
#   'french',
#   'model',
#   'artist',
#   'style',
#   'class',
#   'dude',
#   'pianist',
#   'swag',
#   'concession',
#   'gentlemen',
#   'selfie',
#   'zhouzhuang',
#   'watervillage',
#   'sierra',
#   'format',
#   'building',
#   'architecture',
#   'night',
#   'evening',
#   'design',
#   'nighttime',
#   'frenchconcession',
#   'tianzifang',
#   '田子坊',
#   'format',
#   'four:venue=50589e89e4b02ba60415a295',
#   '蟹',
#   '中華人民共和国',
#   'shi',
#   '孔乙己酒家',
#   '2015',
#   'kina',
#   '2016',
#   'nevs',
#   'magnusjohansson',
#   'trravel',
#   'magnusjo',
#   'magnusjoyahoocom',
#   'butterfly',
#   'wings',
#   'hurricane',
#   'paintingwithlight',
#   'wall',
#   'flap',
#   'aex',
#   'crisis',
#   'stockexchange',
#   'stockmarket',
#   'dowjones',
#   'disruptive',
#   'schilderenmetlicht',
#   'jaapberghoef',
#   'jaapberghoeffotografie',
#   'jaapberghoeffotografiecom',
#   'food',
#   'mushroom',
#   'lunch',
#   'restaurant',
#   'yum',
#   'rice',
#   'sauce',
#   'se',
#   'eat',
#   'oyster',
#   'limbo',
#   'format',
#   'inkwell',
#   'boy',
#   'portrait',
#   'baby',
#   'horizontal',
#   'photography',
#   'se',
#   'wideangle',
#   'indoors',
#   'newborn',
#   '24l',
#   '1dx',
#   'canonef24mmf14liiusm',
#   'eos1dx']}

# %%
cluster={}
for index, row in data_dbscan.sample(n=100).iterrows():
    if row['cluster_num'] != -1.0:
        if row['cluster_num'] not in cluster:
            cluster[row['cluster_num']] = [[row['latitude'],row['longitude']]]
        else:
            cluster[row['cluster_num']] += [[row['latitude'],row['longitude']]]

# %%
for num,coord in cluster.items():
    for co in coord:
        print num,co
# Out:
# 1.0 [31.240483000000001, 121.48523]
# 1.0 [31.236618, 121.484241]
# 1.0 [31.239722, 121.48611099999999]
# 1.0 [31.240542999999999, 121.485868]
# 1.0 [31.238038, 121.486069]
# 1.0 [31.240141000000001, 121.48592499999999]
# 1.0 [31.240119, 121.486277]
# 1.0 [31.239722, 121.48611099999999]
# 2.0 [31.222249999999999, 121.471947]
# 2.0 [31.221488000000001, 121.46981700000001]
# 2.0 [31.223561, 121.469964]
# 2.0 [31.223247000000001, 121.470552]
# 3.0 [31.216691000000001, 121.455917]
# 4.0 [31.240911000000001, 121.49896099999999]
# 4.0 [31.240911000000001, 121.49896099999999]
# 5.0 [31.230277999999998, 121.470556]
# 6.0 [31.232886000000001, 121.464277]
# 6.0 [31.233004999999999, 121.463791]
# 6.0 [31.233332999999998, 121.46466599999999]
# 8.0 [31.238710000000001, 121.49055]
# 10.0 [31.236666, 121.503055]
# 10.0 [31.236663, 121.503078]
# 11.0 [31.209605, 121.464088]
# 11.0 [31.210132999999999, 121.463944]
# 11.0 [31.209804999999999, 121.465386]
# 12.0 [31.264709, 121.48102400000001]
# 12.0 [31.264709, 121.48102400000001]
# 13.0 [31.225601999999999, 121.492813]
# 14.0 [31.225038000000001, 121.469308]
# 15.0 [31.241619, 121.49543]
# 16.0 [31.228994, 121.487022]
# 19.0 [31.227813000000001, 121.476005]
# 19.0 [31.228224000000001, 121.475336]
# 19.0 [31.229279999999999, 121.474608]
# 19.0 [31.227602000000001, 121.47603599999999]

# %%
tags={}
conn = sqlite3.connect(f)
c = conn.cursor()
for num,coord in cluster.items():
    for co in coord:
        c.execute('''SELECT tags FROM photos WHERE latitude == :lat AND longitude == :long''',{'lat': co[0],'long': co[1]})
        conn.commit()
        rows = c.fetchall()
        if rows[0][0] != None:
            if num not in tags:
                tags[num] = rows[0]
            else:
                tags[num] += rows[0]

# %%
blacklist = [
    "chine",
    "shanghai",
    "travel",
    "square",
    "city",
    "china",
    "cn",
    "squareformat",
    "asia",
    "uploaded:by=instagram",
    "shanghaishi",
    "iphoneography",
    "chinese",
    "instagramapp",
    "internations",
    "street",
    u'上海',
    u'中国',
  ]
import operator

# %%
finaltag={}
for num,tags in tags.items():
    wordcount={}
    for word in tags[0].split():
        is_blacklisted = False
        for blword in blacklist:
            if blword == word:
                is_blacklisted = True
        if is_blacklisted == False:
            if word not in wordcount:
                wordcount[word] = 1
            else:
                wordcount[word] += 1
    sorted_word = sorted(wordcount.items(), key=operator.itemgetter(1))
    popular_tags = sorted_word[-5:]
    for popular_tag in popular_tags:
        print popular_tag[0],num
        if num not in finaltag:
                finaltag[num] = [popular_tag[0]]
        else:
            finaltag[num] += [popular_tag[0]]
# Out:
# downtown 1.0
# shopping 1.0
# streetlife 1.0
# cloudy 1.0
# morning 1.0
# ancientchinesearmies 2.0
# matchlock 2.0
# 神机营 2.0
# ming 2.0
# night 4.0
# cityscape 4.0
# tower 4.0
# wayuphigh 4.0
# cityatnight 4.0
# lofi 5.0
# 上海木鴨梨露天餐廳 6.0
# geo:lat=31232885 6.0
# 20150822 6.0
# kmtoin 6.0
# geotagged 6.0
# brannan 11.0
# foursquare:venue=4c330e3366e40f473255c78b 11.0
# 1977 12.0
# 2016上海培训及杭州 16.0
# lorianderik 19.0
# lori 19.0
# erik 19.0
# chinaspree 19.0

# %%
print finaltag
# Out:
# {1.0: [u'downtown', u'shopping', u'streetlife', u'cloudy', u'morning'], 2.0: [u'ancientchinesearmies', u'matchlock', u'\u795e\u673a\u8425', u'ming'], 4.0: [u'night', u'cityscape', u'tower', u'wayuphigh', u'cityatnight'], 5.0: [u'lofi'], 6.0: [u'\u4e0a\u6d77\u6728\u9d28\u68a8\u9732\u5929\u9910\u5ef3', u'geo:lat=31232885', u'20150822', u'kmtoin', u'geotagged'], 11.0: [u'brannan', u'foursquare:venue=4c330e3366e40f473255c78b'], 12.0: [u'1977'], 16.0: [u'2016\u4e0a\u6d77\u57f9\u8bad\u53ca\u676d\u5dde'], 19.0: [u'lorianderik', u'lori', u'erik', u'chinaspree']}

# %%
import pymongo
client = pymongo.MongoClient('localhost', 27017)
db = client.explorify
flickr = db.flickr

# %%
dico_tags =[]
for key in finaltag:
    dico_tag = {}
    dico_tag[str(int(key))] = finaltag[key]
    dico_tags.append(dico_tag)
print dico_tags
flickr.insert_many(dico_tags)
# Out:
# [{'1': [u'downtown', u'shopping', u'streetlife', u'cloudy', u'morning']}, {'2': [u'ancientchinesearmies', u'matchlock', u'\u795e\u673a\u8425', u'ming']}, {'4': [u'night', u'cityscape', u'tower', u'wayuphigh', u'cityatnight']}, {'5': [u'lofi']}, {'6': [u'\u4e0a\u6d77\u6728\u9d28\u68a8\u9732\u5929\u9910\u5ef3', u'geo:lat=31232885', u'20150822', u'kmtoin', u'geotagged']}, {'11': [u'brannan', u'foursquare:venue=4c330e3366e40f473255c78b']}, {'12': [u'1977']}, {'16': [u'2016\u4e0a\u6d77\u57f9\u8bad\u53ca\u676d\u5dde']}, {'19': [u'lorianderik', u'lori', u'erik', u'chinaspree']}]
